# %% [markdown]
# # Research Exercise #9: Finding place names in *The Adventures of Sherlock Holmes* with Named Entity Recognition

# %% [markdown]
# This week, we've been looking at projects that develop models to test out hypotheses about literary works.
#
# We're going to learn how to use a technique called Named Entity Recognition, and we're going to compare two different statistical models –– the default model in a Python library for natural languate processing called `spaCy` and a model developed for "book-length documents" called `BookNLP`. And we'll think a bit about what each of these models defines as a place name.
#
# Below, find the table of contents, including the three questions for you to complete:
#
# **Table of Contents:**
#
# - [What is Named Entity Recognition?](#What-is-Named-Entity-Recognition?)
#     - [How NER works](#How-NER-works:)
# - [Method 1: Using spaCy's training model for named entity recognition](#Method-1:-Using-spaCy's-training-model-for-named-entity-recognition)
#     - [spaCy's model and data](#spaCy's-model-&-data)
#         - [Check-in](#💡-Check-in-💡)
#     - [Getting spaCy set up](#Getting-spaCy-set-up)
#     - [Running spaCy](#Running-spaCy)
#         - [What entities can spaCy's 'Named Entity Recognition' model detect?](#What-entities-can-spaCy's-'Named-Entity-Recognition'-model-detect?)
#     - [Defining a filepath and creating a spaCy document](#Defining-a-filepath-and-creating-a-spaCy-document)
#     - [Output tagged entities in our text](#Output-tagged-entities-in-our-text)
#     - [Visualizing the tagged named entities](#Visualizing-the-tagged-named-entities)
#     - [Output an HTML file with our tagged text](#Output-an-HTML-file-with-our-tagged-text)
#     - [Generating a list of place names from our spaCy document](#Generate-a-list-of-place-names-from-our-spaCy-document)
# - [Method 2: Using BookNLP for named entity recognition](#Method-2:-Using-BookNLP-for-named-entity-recognition)
#     - [BookNLP's model and data](#BookNLP's-model-&-data)
#         - [Reflection:](#💡-Reflection-💡-:)
#         - [What entities can BookNLP's 'Named Entity Recognition' model detect?](#What-entities-can-BookNLP's-'Named-Entity-Recognition'-model-detect?)
#     - [Install BookNLP]()
#     - [Import BookNLP, define parameters and filepaths](#Import-BookNLP,-define-parameters-and-filepaths)
#     - [Run BookNLP](#Run-BookNLP)
#     - [Read in the BookNLP output as a dataframe](#Read-in-the-BookNLP-output-files-as-a-dataframe)
#     - [Generating a list of place names from our BookNLP dataframe](#Generating-a-list-of-place-names-from-our--BookNLP-dataframe)
# - [Your turn!](#Your-turn!)
#     - [Question 1](#Question-1:)
#     - [Question 2](#Question-2:)
#     - [Question 3](#Question-3:)

# %% [markdown]
# ## What is Named Entity Recognition?
#
# "Named Entity Recognition" (NER) is a form of **natural language processing (NLP)** ––that is, the use of computational methods to study "natural language" or language that has evolved through human use.
#
# NER is one techniqued used to extract information from a set of texts using machine learning. Rather than looking for paricular words––like all appearances of the word "London" in Arthur Conan Doyle's Sherlock Holmes, this technique of machine reading training.
#
# We've encountered named entity recognition (NER) before: Elson, Dames, and McKeown, in ["Extracting Social Networks from Literary Fiction,"](https://princeton.instructure.com/courses/6331/files?preview=1351449) use NER to extract character names (see pages 141-142).  Matthew Wilkens, in ["The Geographic Imagination of Civil-War-Era American Fiction,"](https://princeton.instructure.com/courses/6331/files?preview=1351450) uses NER to extract city, state, and country names from his corpus of American fiction (see page 833). Both projects use the [Stanford NER](https://nlp.stanford.edu/software/CRF-NER.html), a named entity recognizer developed by Jenny Finkel and trained on a corpus of tagged [Reuters](https://www.clips.uantwerpen.be/conll2003/ner/) and [Wall Street Journal](https://catalog.ldc.upenn.edu/LDC2003T13) articles (for more on how the model was trained, see the ["Models" section of the Stanfor NER page](https://nlp.stanford.edu/software/CRF-NER.html)).
#
# For this week, we're going to see natural language processing algorithm identifies as a place. We're going to use the [named entity recognition model](https://spacy.io/usage/linguistic-features#named-entities) from the [`spaCy` library](https://spacy.io/usage/spacy-101/#whats-spacy).

# %% [markdown]
# ### How NER works:
#
# From `spaCy`'s [description of the pipeline used to train a model:](https://spacy.io/usage/training)
#
# ![image](../_images/spacy-pipeline.png)
#
# + Named entity recognition is a particular kind of supervised machine learning, which starts by deciding on a set number of categories for entities––these are **labels**.
# + Then, researchers develop a set of texts (usually at least a few hudnred)––this is (**training dataset**. They they go through these texts, carefully labeling (or "tagging") words within each text that fit the categories of named entities (eg persons, places, dates).
# + A statistical **machine learning algorithm** is trained on this dataset––learning how to recognize entities by predicting them based on examples of text and labeled examples in the training data. This training process is done iteratively: examining the labels  and their frequencies within the corpus, learned to predict and assign weights to probability that a given text might fit a lablel, correcting the weights assigned to them, as the algorithm develops a model that might be generalized.
# + The statistical **model** produced by the algorithm is then compared to a new dataset (an "evaluation dataset") that is different from the training dataset. To evaluate how well a model performs, a sample of the evaluation data is checked by hand, with humans verifying how well the model performed at correctly tagging entities, and recording how much the model misssed).
#
#
# A **machine learning algorithm** is a set of algorithms that "learn" or update based on a sample "training dataset".
#
# A **label** (or "tag") is an annotation added by a human to a dataset. For instance, in a training dataset for NER, a human might annnotate with tags around all words that they classify as PERSONS or DATES in a text.
#
# A **training dataset** is a large (at least 100 documents) set of texts used to traing a statistical model to recognize and identify or label parts of text.
#
# An **evaluation dataset**: is a different dataset from the training datset used to evaluate how well the model performs at the task (be it recognizing named entities or recognizing parts-of-speech in a text).
#
# A statistical **model** takes an input and produces an output to produce a mathematical representation of assumptions about predicted patterns in observed data. A model is generated by an initial learning algorithm and which can be used to predict patterns (like classificaitons) in a dataset.
#
# A **named entity**: These can be persons, places, dates, currencies.  Here's [how to can view the named entity categories in the basic spaCy model](#What-entities-can-spaCy's-'Named-Entity-Recognition'-algorithm-detect?).

# %% [markdown]
# ## Method 1: Using `spaCy`'s training model for named entity recognition
#
# ### `spaCy`'s model & data
#
#
# Within spaCy, we're going to use the [EntityRecognizer algogrithm](https://spacy.io/api/entityrecognizer). This is one of many different kinds of tags that spaCy can perform on a text (it can also tag for part-of-speech, or syntactic dependency).
#
# [`spaCy`'s model](https://spacy.io/usage/training) is trained on a dataest that consist of a corpus (that is, a collection of documents)  called [**OntoNotes 5.0**](https://catalog.ldc.upenn.edu/LDC2013T19). Click here to read a little more about what's in this training dataset: https://catalog.ldc.upenn.edu/LDC2013T19

# %% [markdown]
# > ### 💡 Check-in 💡
# Take a look at the training dataset for the default `spaCy` model. What do you notice? What might we need to keep in mind in using this model? What if we wanted to use this model to detect named entities in a literary work, say, a collection of short stories like *The Adventures of Sherlock Holmes?

# %% [markdown]
# **[TYPE YOUR RESPONSE HERE]**

# %% [markdown]
# ### Getting `spaCy` set up

# %%
## Let's install spaCy
# !pip install -U spacy

# %% [markdown]
# ### Importing `spaCy`

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

# %% [markdown]
# ### Downloading & loading the trained `spaCy` model for English
# Here we're going to download the trained pipelines and weights for `spaCy`'s English language model, `en_core_web_sm`. `spaCy` has [models for a wide (though by no means comprehensive) set of languages–––including Japanese, Spanish, Catalan, among many others](https://spacy.io/usage/models#languages).
#
# For more about a Princeton CDH project building models for languages without a `spacy` model, see here: https://newnlp.princeton.edu/about/

# %%
# Download the model for English
# !python -m spacy download en_core_web_sm

# %%
# Import and load the model for English 
import en_core_web_sm
nlp = en_core_web_sm.load()

# %% [markdown]
# ### Running `spaCy`

# %% [markdown]
# #### What entities can `spaCy`'s 'Named Entity Recognition' model detect?
#
# Some of the most common are `PERSON`(for proper names of people), `GPE`(Geo-political entities, which are defined as countries, cities, and states), `TIME`(temporal information), `LOC` (these are non-geopolitical locations, eg regions, bodies of water, mountains, etc), `FAC` (these are built facities, like streets, roads, and bridges), and `ORG` (organizations or corporate entities).
#
# Let's look at what other default labels come with spaCy:

# %%
# Let's define a variable "list_of_ner_labels" and set that equal to the NLP pipe labels in spaCy's 'NER' algorithm
list_of_ner_labels = nlp.pipe_labels['ner']


# Print out the number of labels
print('Number of labels in the default spaCy Named Entity Recognizer:\n', len(list_of_ner_labels))
# Print out the names of the differe labels
print('Available labels in spaCy default Named Entity Recognizer:\n', list_of_ner_labels)
# Out:
# Number of labels in the default spaCy Named Entity Recognizer:
#  18
# Available labels in spaCy default Named Entity Recognizer:
#  ['CARDINAL', 'DATE', 'EVENT', 'FAC', 'GPE', 'LANGUAGE', 'LAW', 'LOC', 'MONEY', 'NORP', 'ORDINAL', 'ORG', 'PERCENT', 'PERSON', 'PRODUCT', 'QUANTITY', 'TIME', 'WORK_OF_ART']

# %% [markdown]
# ### Defining a filepath and running `spaCy` on our file
#
# Below, we define our file paths and create a `spaCy` document by running `nlp()` on our text file.

# %%
filepath = "../_datasets/texts/literature/Arthur-Conan-Doyle-The-Adventures-of-Sherlock-Holmes.txt"
text = open(filepath, encoding='utf-8').read()
spacy_document = nlp(text)

# %% [markdown]
# ### Output tagged entities in our text
# Once we have our `spaCy` document, we can access some of the tagged text using `spacy_document.ents`. This `spacy_document.ents` stores information about every entity (e.g.  **the string text of that entity**, the **starting character of the text string for that entity**, the **ending character of that entity**, and the **label** assigned to that entity, (eg PERSON, GPE, DATE, TIME, etc)).
#
# We can query it to retrieve of information about our tagged text, such as the text string (`ent.text`), the starting (`ent.start_char`) and ending characters of the tagged text (`ent.end_char`) and the label that the entity has been tagged as (`ent.label_`).
#
# Let's use a for loop to iterate over all the entities that the spaCy algorithm tagged:

# %%
print("entity | entity_start_character | entity_end_character | entity_label\n")
for ent in spacy_document.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# entity | entity_start_character | entity_end_character | entity_label
#
# The Adventures of Sherlock Holmes 1 34 WORK_OF_ART
# Arthur Conan Doyle 39 57 ORG
# Bohemia 93 100 GPE
# The Red-Headed League 111 132 ORG
# Identity 153 161 ORG
# The Boscombe Valley Mystery 172 199 FAC
# Five 214 218 CARDINAL
# The Man 241 248 WORK_OF_ART
# The Adventure of the Blue Carbuncle
#    VIII 280 323 WORK_OF_ART
# The Adventure of the Speckled Band 326 360 WORK_OF_ART
# The Adventure of the Engineer’s Thumb 371 408 WORK_OF_ART
# X.      412 419 PERSON
# The Adventure of the Noble Bachelor
#    XI 419 460 WORK_OF_ART
# The Adventure of the Beryl Coronet 465 499 WORK_OF_ART
# XII 503 506 ORG
# The Adventure of the Copper Beeches
#
#
#
#
# I. A SCANDAL IN BOHEMIA 510 573 WORK_OF_ART
# Irene Adler 801 812 PERSON
# one 837 840 CARDINAL
# Irene 1679 1684 PERSON
# Holmes 1750 1756 GPE
# first 1905 1910 ORDINAL
# Holmes 2008 2014 ORG
# Bohemian 2065 2073 NORP
# Baker Street 2108 2120 FAC
# from week to week 2166 2183 DATE
# Odessa 2627 2633 PERSON
# Trepoff 2653 2660 PERSON
# Atkinson 2719 2727 ORG
# Trincomalee 2740 2751 ORG
# Holland 2864 2871 GPE
# daily 2968 2973 DATE
# One night 3031 3040 TIME
# the twentieth of March, 1888 3051 3079 DATE
# Baker Street 3195 3207 FAC
# Holmes 3398 3404 PERSON
# Watson 4392 4398 PERSON
# seven and a 4421 4432 TIME
# Watson 4561 4567 PERSON
# Holmes 4850 4856 GPE
# a few centuries ago 4938 4957 DATE
# Thursday 4999 5007 DATE
# Mary
# Jane 5116 5125 PERSON
# six 5459 5462 CARDINAL
# London 5775 5781 GPE
# some hundreds 6792 6805 CARDINAL
# seventeen 6980 6989 CARDINAL
# one 7142 7145 CARDINAL
# two 7149 7152 CARDINAL
# a quarter to eight o’clock 7467 7493 DATE
# one 7611 7614 CARDINAL
# Europe 7638 7644 LOC
# all quarters 7805 7817 DATE
# that hour 7855 7864 TIME
# one 8089 8092 CARDINAL
# under half 8439 8449 CARDINAL
# Holmes 8544 8550 PERSON
# English 8566 8573 LANGUAGE
# Holmes 8775 8781 PERSON
# German 8925 8931 NORP
# Continental Gazetteer 9068 9089 ORG
# Eglonitz 9152 9160 ORG
# Egria 9174 9179 GPE
# German 9192 9198 NORP
# Bohemia 9219 9226 GPE
# Carlsbad 9241 9249 ORG
# Wallenstein 9298 9309 PERSON
# Bohemia 9517 9524 GPE
# German 9584 9590 NORP
# quarters 9684 9692 DATE
# Frenchman 9706 9715 PERSON
# Russian 9719 9726 NORP
# German 9766 9772 NORP
# German 9872 9878 NORP
# Bohemian 9895 9903 NORP
# A hundred 10306 10315 CARDINAL
# fifty 10320 10325 CARDINAL
# Watson 10370 10376 PERSON
# Holmes 10437 10443 GPE
# Boswell 10508 10515 ORG
# Holmes 10925 10931 PERSON
# less than six feet 10975 10993 QUANTITY
# Hercules 11046 11054 GPE
# England 11107 11114 GPE
# German 12136 12142 NORP
# Holmes 12282 12288 PERSON
# Watson 12328 12334 PERSON
# the Count Von Kramm 12452 12471 PRODUCT
# Bohemian 12475 12483 NORP
# Holmes 12719 12725 PERSON
# two years 13001 13010 DATE
# European 13166 13174 NORP
# Holmes 13204 13210 PERSON
# I. 13218 13220 ORG
# august 13288 13294 DATE
# Holmes 13483 13489 PERSON
# one 13653 13656 CARDINAL
# Europe 13685 13691 LOC
# House of Ormstein 13743 13760 ORG
# Bohemia 13782 13789 PERSON
# Holmes 13830 13836 PERSON
# Europe 14086 14092 LOC
# Holmes
#  14094 14101 PERSON
# Majesty 14183 14190 PERSON
# I am the King 14501 14514 WORK_OF_ART
# Holmes 14578 14584 PERSON
# Wilhelm Gottsreich Sigismond von 14656 14688 PERSON
# Grand Duke 14699 14709 ORG
# Cassel-Felstein 14713 14728 ORG
# King of
# Bohemia 14745 14760 ORG
# Prague 15113 15119 GPE
# Holmes 15184 15190 PERSON
# Some five years ago 15252 15271 DATE
# Warsaw 15299 15305 GPE
# Irene Adler 15362 15373 PERSON
# Holmes 15466 15472 PERSON
# many years 15503 15513 DATE
# Hebrew 15766 15772 LANGUAGE
# Holmes 15883 15889 PERSON
# New Jersey 15905 15915 GPE
# the year 1858 15919 15932 DATE
# La Scala 15949 15957 PERSON
# Prima 15964 15969 GPE
# Imperial Opera 15976 15990 ORG
# Warsaw 15994 16000 GPE
# London 16048 16054 GPE
# Majesty 16367 16374 PERSON
# Pooh 16528 16532 PERSON
# Imitated 16605 16613 PRODUCT
# Bought 16636 16642 WORK_OF_ART
# Majesty 16715 16722 PERSON
# thirty now 16881 16891 DATE
# Five 17034 17038 CARDINAL
# Holmes 17253 17259 PERSON
# King 17363 17367 ORG
# Clotilde 17534 17542 NORP
# von Saxe-Meningen 17551 17568 PERSON
# second 17570 17576 ORDINAL
# King of
# Scandinavia 17593 17612 ORG
# Irene Adler 17784 17795 PERSON
# next Monday 18310 18321 DATE
# three days 18343 18353 DATE
# Holmes 18365 18371 PERSON
# one 18420 18423 CARDINAL
# two 18427 18430 CARDINAL
# Majesty 18488 18495 PERSON
# London 18521 18527 GPE
# Langham 18583 18590 PERSON
# Von Kramm 18619 18628 PERSON
# three hundred pounds 19024 19044 QUANTITY
# seven hundred 19057 19070 CARDINAL
# Holmes 19092 19098 PERSON
# Briony Lodge 19217 19229 PERSON
# Serpentine Avenue 19231 19248 ORG
# St. John’s Wood 19250 19265 FAC
# Holmes 19269 19275 PERSON
# One 19296 19299 CARDINAL
# Majesty 19394 19401 PERSON
# Watson 19479 19485 PERSON
# three o’clock 19617 19630 TIME
# II 19690 19692 ORG
# three o’clock 19698 19711 TIME
# Baker Street 19731 19743 FAC
# Holmes 19749 19755 PERSON
# eight o’clock in the morning 19844 19872 TIME
# two 20123 20126 CARDINAL
# three 20982 20987 CARDINAL
# five minutes 21100 21112 TIME
# some minutes 21262 21274 TIME
# Irene Adler 21632 21643 PERSON
# a little after eight o’clock this morning 21736 21777 TIME
# one 21886 21889 CARDINAL
# Briony Lodge 21957 21969 PERSON
# two 22066 22069 CARDINAL
# Chubb 22079 22084 ORG
# English 22219 22226 LANGUAGE
# one 22610 22613 CARDINAL
# half-and-half 22736 22749 DATE
# two 22751 22754 CARDINAL
# Miss Adler 22826 22836 PERSON
# half a dozen 22856 22868 CARDINAL
# Irene Adler 23013 23024 PERSON
# five every day 23244 23258 DATE
# seven 23275 23280 CARDINAL
# only one 23358 23366 CARDINAL
# Godfrey 23503 23510 PERSON
# the Inner Temple 23522 23538 FAC
# a dozen 23612 23619 CARDINAL
# Serpentine 23631 23641 ORG
# Briony Lodge 23750 23762 ORG
# This Godfrey Norton 23815 23834 WORK_OF_ART
# Briony Lodge 24238 24250 ORG
# Briony Lodge 24634 24646 PERSON
# about half an hour 24965 24983 TIME
# first 25338 25343 ORDINAL
# Gross &
# Hankey’s 25347 25363 ORG
# Regent Street 25367 25380 LOC
# the Church of St. Monica 25394 25418 ORG
# Half 25441 25445 CARDINAL
# twenty minutes 25471 25485 TIME
# only half 25646 25655 CARDINAL
# ‘The Church of St. Monica, John 25945 25976 WORK_OF_ART
# half 25995 25999 CARDINAL
# twenty minutes 26031 26045 TIME
# Watson 26083 26089 PERSON
# The Church of St.
#  26309 26327 ORG
# half 26349 26353 CARDINAL
# twenty
# minutes 26385 26399 TIME
# twenty-five minutes 26409 26428 TIME
# two 26763 26766 CARDINAL
# three 26870 26875 CARDINAL
# three 27028 27033 CARDINAL
# Godfrey Norton 27070 27084 PERSON
# only three minutes 27224 27242 TIME
# half 27275 27279 CARDINAL
# Irene Adler 27500 27511 PERSON
# Godfrey Norton 27526 27540 PERSON
# five 28601 28605 CARDINAL
# this evening 28905 28917 TIME
# Turner 29247 29253 PERSON
# two hours 29478 29487 TIME
# Irene 29528 29533 PERSON
# Briony Lodge 29601 29613 ORG
# only one 29726 29734 CARDINAL
# Four or five minutes 29988 30008 QUANTITY
# ten minutes 30727 30738 TIME
# a few minutes 31169 31182 TIME
# Nonconformist 31232 31245 ORG
# John Hare 31406 31415 PERSON
# Holmes 31466 31472 PERSON
# a quarter past six 31705 31723 DATE
# Baker Street 31737 31749 ORG
# ten minutes 31771 31782 TIME
# Serpentine 31822 31832 GPE
# dusk 31856 31860 TIME
# Briony Lodge 31936 31948 PERSON
# two 32342 32345 CARDINAL
# Holmes 32508 32514 PERSON
# Godfrey Norton 32723 32737 PERSON
# King 33027 33031 ORG
# Two 33079 33082 CARDINAL
# a few days 33625 33635 DATE
# Pshaw! 33751 33757 WORK_OF_ART
# Briony Lodge 34176 34188 ORG
# two 34447 34450 CARDINAL
# Holmes
#  34781 34788 PERSON
# one 34995 34998 CARDINAL
# Briony Lodge 35937 35949 ORG
# Holmes 36132 36138 PERSON
# Holmes 36522 36528 GPE
# Holmes 37328 37334 GPE
# ten minutes 37474 37485 TIME
# some few minutes 37611 37627 TIME
# one 37653 37656 CARDINAL
# the Edgeware Road 37697 37714 FAC
# the evening 38147 38158 TIME
# the Darlington Substitution Scandal 39011 39046 ORG
# Arnsworth Castle 39084 39100 GPE
# to-day 39230 39236 DATE
# half 39618 39622 CARDINAL
# King 40107 40111 ORG
# Majesty 40344 40351 PERSON
# eight in the morning 40418 40438 TIME
# King 40613 40617 ORG
# Baker Street 40650 40662 FAC
# Good-night 40762 40772 TIME
# Sherlock Holmes 40781 40796 PERSON
# Holmes 40978 40984 PERSON
# III 41075 41078 PERSON
# Baker Street 41092 41104 FAC
# the King of Bohemia 41183 41202 ORG
# Briony Lodge 41573 41585 PERSON
# Irene Adler 41589 41600 PERSON
# Holmes 41623 41629 PERSON
# Married! 41633 41641 WORK_OF_ART
# Yesterday 41651 41660 DATE
# English 41687 41694 NORP
# Norton 41708 41714 ORG
# Majesty 41831 41838 PERSON
# Majesty 41923 41930 PERSON
# Majesty 41958 41965 PERSON
# Majesty 42021 42028 ORG
# Serpentine Avenue 42217 42234 FAC
# Briony Lodge 42249 42261 PERSON
# Sherlock Holmes 42389 42404 PERSON
# Holmes 42439 42445 PERSON
# this morning 42600 42612 TIME
# Charing Cross 42653 42666 ORG
# England 42792 42799 GPE
# King 42975 42979 ORG
# Holmes 43151 43157 PERSON
# Irene Adler 43305 43316 PERSON
# evening 43328 43335 TIME
# Sherlock Holmes 43375 43390 WORK_OF_ART
# Esq 43392 43395 GPE
# three 43461 43466 CARDINAL
# midnight 43501 43509 TIME
# the preceding night 43513 43532 TIME
# months ago 43809 43819 DATE
# King 43854 43858 ORG
# John 44280 44284 PERSON
# Sherlock Holmes 44541 44556 PERSON
# Sherlock Holmes 45247 45262 PERSON
# the King of Bohemia 45364 45383 ORG
# three 45401 45406 CARDINAL
# Majesty 45666 45673 PERSON
# Holmes 45681 45687 PERSON
# King 45844 45848 ORG
# Majesty 46003 46010 PERSON
# Holmes 46275 46281 GPE
# Majesty 46446 46453 PERSON
# King 46620 46624 ORG
# Sherlock Holmes 46803 46818 PERSON
# Irene Adler 46963 46974 PERSON
# THE RED-HEADED LEAGUE
#
#
#  I 47077 47103 ORG
# Sherlock Holmes 47135 47150 PERSON
# one day 47152 47159 DATE
# Holmes 47360 47366 PERSON
# Watson 47493 47499 PERSON
# Wilson 47657 47663 PERSON
# Holmes 47981 47987 PERSON
# Watson 48113 48119 PERSON
# the other day 48531 48544 DATE
# Mary Sutherland 48613 48628 PERSON
# Jabez Wilson 49048 49060 PERSON
# this morning 49103 49115 TIME
# Wilson 49689 49695 PERSON
# Watson 49804 49810 PERSON
# thousands 50065 50074 CARDINAL
# British 50777 50784 NORP
# obese 50796 50801 NORP
# Albert 50976 50982 PERSON
# Freemason 51557 51566 PERSON
# China 51588 51593 GPE
# Jabez Wilson 51690 51702 PERSON
# Holmes 51859 51865 PERSON
# Freemasonry 52173 52184 ORG
# five 52471 52475 CARDINAL
# China 52584 52589 GPE
# China 52690 52695 GPE
# China 52881 52886 GPE
# Chinese 52915 52922 NORP
# Jabez Wilson 53002 53014 PERSON
# first 53072 53077 ORDINAL
# Watson 53185 53191 PERSON
# Holmes 53199 53205 PERSON
# Wilson 53414 53420 PERSON
# TO THE RED-HEADED LEAGUE: 53648 53673 WORK_OF_ART
# Ezekiah Hopkins 53712 53727 ORG
# Lebanon 53732 53739 GPE
# Pennsylvania 53741 53753 GPE
# U.S.A. 53755 53761 GPE
# 4 53852 53853 MONEY
# the age of twenty-one years 53950 53977 DATE
# Monday 54012 54018 DATE
# eleven o’clock 54023 54037 TIME
# Duncan Ross 54042 54053 PERSON
# League 54077 54083 ORG
# 7 54085 54086 CARDINAL
# Fleet Street 54101 54113 FAC
# Wilson 54378 54384 PERSON
# first 54529 54534 ORDINAL
# The Morning Chronicle 54593 54614 WORK_OF_ART
# April 27, 1890 54619 54633 DATE
# Just two months ago 54635 54654 DATE
# Wilson 54679 54685 PERSON
# Sherlock Holmes 54739 54754 PERSON
# Jabez Wilson 54762 54774 PERSON
# Coburg Square 54839 54852 FAC
# two 54992 54995 CARDINAL
# half 55102 55106 CARDINAL
# Sherlock Holmes 55193 55208 PERSON
# Vincent Spaulding 55224 55241 PERSON
# Holmes 55347 55353 PERSON
# Wilson 55799 55805 PERSON
# fourteen 56158 56166 CARDINAL
# three 56335 56340 CARDINAL
# first 56430 56435 ORDINAL
# this day eight weeks 56527 56547 DATE
# Wilson 56623 56629 PERSON
# the League of the
#  56728 56746 ORG
# Holmes 57102 57108 PERSON
# weeks 57216 57221 DATE
# the League of the Red-headed 57400 57428 ORG
# one 57535 57538 CARDINAL
# a couple of hundred a year 57610 57636 CARDINAL
# one 57703 57706 CARDINAL
# some years 57838 57848 DATE
# I. 57940 57942 ORG
# ‘Well 57945 57950 WORK_OF_ART
# American 58169 58177 NORP
# Ezekiah Hopkins 58191 58206 ORG
# millions 58618 58626 CARDINAL
# Londoners 58746 58755 PRODUCT
# American 58780 58788 NORP
# London 58806 58812 GPE
# Wilson 59052 59058 PERSON
# a few hundred pounds 59179 59199 MONEY
# Vincent Spaulding 59446 59463 PERSON
# Holmes 59815 59821 PERSON
# south 59835 59840 GPE
# Pope’s Court 60007 60019 ORG
# lemon, orange 60218 60231 ORG
# Irish 60240 60245 NORP
# Spaulding 60275 60284 ORG
# Holmes 60855 60861 PERSON
# Jabez Wilson 61549 61561 PERSON
# one 61818 61821 CARDINAL
# wrung my
#  61911 61920 ORG
# cobbler 62392 62399 ORG
# Duncan Ross 62767 62778 PERSON
# Wilson 62889 62895 PERSON
# ‘Dear me 62977 62985 WORK_OF_ART
# sorry
#  63040 63046 PERSON
# Holmes 63271 63277 PERSON
# a few
# minutes 63370 63383 TIME
# I. 63695 63697 ORG
# Wilson 63732 63738 PERSON
# Vincent Spaulding 63746 63763 PERSON
# the hours 63829 63838 TIME
# two 63860 63863 CARDINAL
# an evening 63914 63924 TIME
# Holmes 63930 63936 PERSON
# Thursday 63949 63957 DATE
# Friday 63962 63968 DATE
# evening 63969 63976 TIME
# pay-day 63999 64006 DATE
# mornings 64062 64070 TIME
# only four hours 64598 64613 TIME
# Duncan Ross 64700 64711 PERSON
# Encyclopædia Britannica 64851 64874 PERSON
# first 64890 64895 ORDINAL
# Jabez Wilson 65095 65107 PERSON
# all day 65392 65399 DATE
# evening 65408 65415 TIME
# Encyclopædia Britannica 65738 65761 PERSON
# Vincent
# Spaulding 65764 65781 PERSON
# a penny 65955 65962 MONEY
# seven 66004 66009 CARDINAL
# Pope’s Court 66054 66066 ORG
# Duncan Ross 66185 66196 PERSON
# two o’clock 66376 66387 TIME
# good-day 66399 66407 DATE
# Holmes 66539 66545 PERSON
# Saturday 66554 66562 DATE
# four 66600 66604 CARDINAL
# week 66630 66634 DATE
# the same next week 66650 66668 DATE
# the same the week 66674 66691 DATE
# ten 66728 66731 CARDINAL
# two 66763 66766 CARDINAL
# Duncan Ross 66783 66794 PERSON
# Eight weeks 67092 67103 DATE
# Abbots 67151 67157 ORG
# Armour 67174 67180 PERSON
# Attica 67202 67208 PERSON
# ten o’clock 67517 67528 TIME
# THE RED-HEADED LEAGUE IS DISSOLVED 67801 67835 WORK_OF_ART
# October 9, 1890 67837 67852 DATE
# Sherlock Holmes 67857 67872 PERSON
# Holmes 68279 68285 PERSON
# half 68337 68341 CARDINAL
# Duncan Ross 68960 68971 PERSON
# ‘Well 69021 69026 WORK_OF_ART
# 4 69059 69060 CARDINAL
# William Morris 69133 69147 PERSON
# yesterday 69265 69274 DATE
# 17 69365 69367 CARDINAL
# Edward Street 69373 69386 PERSON
# St. Paul’s 69393 69403 FAC
# Holmes 69427 69433 PERSON
# William Morris 69558 69572 PERSON
# Duncan Ross 69580 69591 PERSON
# Holmes 69629 69635 PERSON
# Saxe-Coburg Square 69654 69672 ORG
# Holmes 69848 69854 PERSON
# Holmes 70069 70075 PERSON
# first 70261 70266 ORDINAL
# Jabez Wilson 70308 70320 PERSON
# four pound 70340 70350 QUANTITY
# Holmes 70412 70418 PERSON
# some £ 30 70550 70559 MONEY
# first 70984 70989 ORDINAL
# one 70991 70994 CARDINAL
# two 70998 71001 CARDINAL
# Wilson 71017 71023 PERSON
# first 71053 71058 ORDINAL
# About a month 71136 71149 DATE
# a dozen 71253 71260 CARDINAL
# half 71339 71343 CARDINAL
# Vincent Spaulding 71393 71410 PERSON
# thirty 71505 71511 CARDINAL
# Holmes 71561 71567 PERSON
# Holmes 71800 71806 PERSON
# morning 72031 72038 TIME
# Wilson 72061 72067 PERSON
# day 72145 72148 DATE
# two 72152 72155 CARDINAL
# To-day 72157 72163 DATE
# Saturday 72167 72175 DATE
# Monday 72196 72202 DATE
# Well, Watson 72235 72247 WORK_OF_ART
# Holmes 72255 72261 PERSON
# Holmes 72422 72428 PERSON
# three 72753 72758 CARDINAL
# fifty minutes 72814 72827 TIME
# the St. James’s Hall 73273 73293 ORG
# this afternoon 73294 73308 TIME
# Watson 73344 73350 PERSON
# a few
# hours 73386 73397 TIME
# first 73530 73535 ORDINAL
# German 73615 73621 NORP
# Italian 73684 73691 NORP
# French 73695 73701 NORP
# Underground 73784 73795 FAC
# Aldersgate 73806 73816 ORG
# four 73990 73994 CARDINAL
# two 74010 74013 CARDINAL
# laurel bushes 74134 74147 ORG
# Three 74216 74221 CARDINAL
# two 74739 74742 CARDINAL
# three 74746 74751 CARDINAL
# Holmes 74912 74918 PERSON
# Strand 74980 74986 ORG
# Third 74991 74996 ORDINAL
# fourth 75004 75010 ORDINAL
# Holmes 75101 75107 PERSON
# fourth 75155 75161 ORDINAL
# London 75178 75184 GPE
# third 75245 75250 ORDINAL
# Wilson 75318 75324 PERSON
# Saxe-Coburg Square 75743 75761 ORG
# Saxe-Coburg Square 75899 75917 ORG
# Holmes 76490 76496 PERSON
# London 76664 76670 GPE
# Coburg 76741 76747 PERSON
# Suburban Bank 76771 76784 ORG
# the Vegetarian Restaurant 76786 76811 ORG
# afternoon 77282 77291 TIME
# Holmes 77494 77500 GPE
# Holmes 77519 77525 PERSON
# days 78003 78007 DATE
# that afternoon 78405 78419 TIME
# some hours 78703 78713 TIME
# Coburg Square 78732 78745 FAC
# Saturday 78904 78912 DATE
# Ten 78994 78997 CARDINAL
# Baker Street 79037 79049 FAC
# Sherlock
# Holmes 79395 79410 ORG
# Kensington 79688 79698 GPE
# Holmes 80023 80029 GPE
# quarter-past nine 80259 80276 DATE
# Park 80329 80333 PRODUCT
# Oxford Street 80350 80363 FAC
# Baker Street 80367 80379 FAC
# Two 80381 80384 CARDINAL
# Holmes 80519 80525 PERSON
# two 80556 80559 CARDINAL
# Peter
# Jones 80593 80604 PERSON
# Holmes 80780 80786 PERSON
# Watson 80866 80872 PERSON
# Jones 80895 80900 PERSON
# Scotland Yard 80905 80918 ORG
# Merryweather 80948 80960 PERSON
# Jones 81072 81077 PERSON
# Merryweather 81304 81316 PERSON
# Holmes 81374 81380 PERSON
# Sholto 81657 81663 PRODUCT
# Agra 81679 81683 PERSON
# Jones 81777 81782 PERSON
# first 81887 81892 ORDINAL
# Saturday 81893 81901 DATE
# night 81902 81907 TIME
# seven-and-twenty years 81912 81934 DATE
# Sherlock Holmes 81998 82013 PERSON
# Merryweather 82146 82158 PERSON
# some £ 82178 82184 MONEY
# 30,000 82185 82191 MONEY
# Jones 82206 82211 PERSON
# John Clay 82273 82282 PERSON
# Merryweather 82348 82360 PERSON
# London 82471 82477 GPE
# John Clay 82511 82520 PERSON
# Eton 82583 82587 PERSON
# Oxford 82592 82598 ORG
# Scotland 82754 82762 GPE
# one
# week 82763 82771 DATE
# Cornwall 82819 82827 GPE
# years 82865 82870 DATE
# one 82984 82987 CARDINAL
# two 82991 82994 CARDINAL
# John Clay 83022 83031 PERSON
# two 83160 83163 CARDINAL
# first 83178 83183 ORDINAL
# Watson 83192 83198 PERSON
# second 83224 83230 ORDINAL
# Sherlock Holmes 83234 83249 PERSON
# afternoon 83367 83376 TIME
# Farrington Street 83459 83476 FAC
# Merryweather 83538 83550 PERSON
# Jones 83641 83646 PERSON
# Merryweather 84049 84061 PERSON
# Merryweather 84337 84349 PERSON
# third 84461 84466 ORDINAL
# Holmes 84602 84608 PERSON
# Merryweather 84693 84705 PERSON
# Holmes
#  84898 84905 PERSON
# Merryweather 85102 85114 PERSON
# Holmes 85197 85203 GPE
# A few seconds 85341 85354 TIME
# at least an hour 85455 85471 TIME
# a minute 85601 85609 TIME
# one 85785 85788 CARDINAL
# London 85806 85812 GPE
# Merryweather 85824 85836 PERSON
# London 85950 85956 GPE
# French 86033 86039 NORP
# French 86148 86154 NORP
# some months ago 86185 86200 DATE
# 30,000 86259 86265 CARDINAL
# the Bank of France 86281 86299 ORG
# 2,000 86452 86457 CARDINAL
# Holmes 86702 86708 PERSON
# an hour 86786 86793 TIME
# Merryweather 86843 86855 PERSON
# first 87186 87191 ORDINAL
# Watson 87496 87502 PERSON
# one 88081 88084 CARDINAL
# Holmes 88105 88111 PERSON
# Saxe-Coburg Square 88150 88168 ORG
# Jones 88214 88219 PERSON
# two 88248 88251 CARDINAL
# an
# hour 88431 88438 TIME
# Jones 88839 88844 PERSON
# first 89020 89025 ORDINAL
# a minute 89307 89315 TIME
# one 89610 89613 CARDINAL
# one 89931 89934 CARDINAL
# Jump 90211 90215 PERSON
# Archie 90217 90223 GPE
# Sherlock Holmes 90256 90271 PERSON
# Jones 90399 90404 PERSON
# Holmes 90482 90488 PERSON
# John Clay 90593 90602 PERSON
# Holmes 90610 90616 PERSON
# three 90803 90808 CARDINAL
# Holmes 90848 90854 PERSON
# Jones 91070 91075 PERSON
# Jones 91449 91454 PERSON
# march upstairs 91513 91527 DATE
# John Clay 91623 91632 PERSON
# three 91673 91678 CARDINAL
# Holmes 91755 91761 PERSON
# Merryweather 91773 91785 PERSON
# one 92069 92072 CARDINAL
# two 92076 92079 CARDINAL
# John
# Clay 92123 92132 PERSON
# Holmes 92140 92146 PERSON
# Watson 92417 92423 PERSON
# the early hours 92442 92457 TIME
# Baker Street 92518 92530 FAC
# first 92567 92572 ORDINAL
# Encyclopædia 92697 92709 ORG
# hours 92790 92795 TIME
# Clay’s 92937 92943 LAW
# 4 a week 93005 93013 DATE
# thousands 93092 93101 CARDINAL
# one 93134 93137 CARDINAL
# every morning 93266 93279 TIME
# the week 93283 93291 DATE
# half 93353 93357 CARDINAL
# one 94087 94090 CARDINAL
# London 94135 94141 GPE
# hours 94870 94875 TIME
# Suburban Bank 94993 95006 ORG
# Scotland Yard 95132 95145 ORG
# Jabez Wilson 95406 95418 PERSON
# Saturday 95595 95603 DATE
# two days 95669 95677 DATE
# one 95996 95999 CARDINAL
# I. 96145 96147 ORG
# George Sand 96316 96327 PERSON
# IDENTITY 96349 96357 ORG
# Sherlock Holmes 96383 96398 PERSON
# Baker Street 96455 96467 FAC
# stale
#  97038 97044 ORG
# Holmes 97446 97452 PERSON
# three 97918 97923 CARDINAL
# first 98105 98110 ORDINAL
# half 98182 98186 CARDINAL
# some weeks 99363 99373 DATE
# the King of Bohemia 99404 99423 ORG
# Irene Adler 99471 99482 PERSON
# Holland 99622 99629 GPE
# one 99770 99773 CARDINAL
# two 99777 99780 CARDINAL
# ten or 99873 99879 TIME
# one 100334 100337 CARDINAL
# Marseilles 100397 100407 PERSON
# very many minutes 100532 100549 TIME
# one 100572 100575 CARDINAL
# London 100728 100734 GPE
# Devonshire 100968 100978 GPE
# Holmes 101369 101375 PERSON
# Mary Sutherland 101993 102008 PERSON
# first 102474 102479 ORDINAL
# Holmes 102739 102745 PERSON
# Holmes 102815 102821 PERSON
# Etherege 103026 103034 PERSON
# Holmes 103132 103138 PERSON
# a hundred a year 103207 103223 DATE
# Hosmer Angel 103343 103355 PERSON
# Sherlock
# Holmes 103420 103435 ORG
# Mary
# Sutherland 103563 103578 PERSON
# Windibank 103681 103690 PERSON
# Holmes 103964 103970 PERSON
# five years 104113 104123 DATE
# two months 104128 104138 DATE
# Holmes 104252 104258 PERSON
# nearly fifteen years 104331 104351 DATE
# Hardy 104497 104502 PERSON
# Windibank 104530 104539 PERSON
# Sherlock Holmes 104774 104789 ORG
# Ned 105072 105075 PERSON
# New Zealand 105098 105109 GPE
# 4½ per cent 105124 105135 MONEY
# Two thousand 105137 105149 CARDINAL
# five hundred pounds 105150 105169 QUANTITY
# Holmes 105257 105263 PERSON
# about £ 60 105492 105502 MONEY
# Holmes 105548 105554 PERSON
# Windibank 105763 105772 PERSON
# every quarter 105791 105804 DATE
# fifteen to twenty 105958 105975 CARDINAL
# a day 105986 105991 DATE
# Holmes 106048 106054 PERSON
# Watson 106080 106086 PERSON
# Hosmer 106196 106202 PERSON
# Sutherland 106236 106246 PERSON
# first 106320 106325 ORDINAL
# Windibank 106484 106493 PERSON
# Sunday 106610 106616 DATE
# France 106981 106987 GPE
# Hardy 107055 107060 PERSON
# Holmes 107151 107157 PERSON
# Windibank 107174 107183 PERSON
# France 107199 107205 GPE
# Hosmer Angel 107522 107534 PERSON
# next day 107585 107593 DATE
# Hosmer Angel 107758 107770 PERSON
# Hosmer Angel 108131 108143 PERSON
# France 108213 108219 GPE
# a week 108229 108235 DATE
# Hosmer 108241 108247 ORG
# every
# day 108391 108400 DATE
# Holmes 108548 108554 PERSON
# first 108582 108587 ORDINAL
# Angel 108618 108623 PERSON
# Holmes 108724 108730 PERSON
# the Leadenhall Street Post Office 108933 108966 ORG
# Holmes 109394 109400 PERSON
# Holmes 109481 109487 PERSON
# Hosmer Angel 109633 109645 PERSON
# Holmes 109677 109683 PERSON
# evening 109721 109728 TIME
# Windibank 110192 110201 PERSON
# France 110232 110238 GPE
# Hosmer Angel 110247 110259 PERSON
# first 110601 110606 ORDINAL
# the week 110688 110696 DATE
# Holmes 110891 110897 PERSON
# only a few years 110954 110970 DATE
# Bordeaux 111055 111063 ORG
# French 111091 111097 NORP
# morning 111150 111157 TIME
# England 111233 111240 GPE
# Friday 111335 111341 DATE
# St. Saviour’s 111414 111427 FAC
# King’s
# Cross 111434 111446 ORG
# St. Pancras
# Hotel 111496 111513 ORG
# two 111565 111568 CARDINAL
# four 111625 111629 CARDINAL
# four 111735 111739 CARDINAL
# last Friday 112004 112015 DATE
# Holmes 112021 112027 PERSON
# morning 112269 112276 TIME
# One 112924 112927 CARDINAL
# Hosmer 113188 113194 WORK_OF_ART
# Hosmer 113433 113439 ORG
# night 113650 113655 TIME
# Holmes 113787 113793 PERSON
# Hosmer Angel 113987 113999 PERSON
# last Saturday 114310 114323 DATE
# Chronicle 114327 114336 PERSON
# four 114381 114385 CARDINAL
# 31 114443 114445 CARDINAL
# Camberwell 114458 114468 ORG
# Angel 114477 114482 PERSON
# Westhouse & Marbank 114582 114601 ORG
# Holmes 114896 114902 PERSON
# Hosmer 114945 114951 ORG
# Sherlock Holmes 115271 115286 PERSON
# a few minutes 115302 115315 TIME
# Hague 115959 115964 GPE
# last
# year 115965 115974 DATE
# one 116016 116019 CARDINAL
# two 116023 116026 CARDINAL
# Watson 116224 116230 PERSON
# Sherlock Holmes 117051 117066 PERSON
# Watson 117131 117137 PERSON
# general impressions 117356 117375 ORG
# first 117427 117432 ORDINAL
# first 117501 117506 ORDINAL
# one 118363 118366 CARDINAL
# One 118431 118434 CARDINAL
# two 118460 118463 CARDINAL
# five 118485 118489 CARDINAL
# first 118512 118517 ORDINAL
# third 118519 118524 ORDINAL
# fifth 118530 118535 ORDINAL
# half 118640 118644 CARDINAL
# this morning 119143 119155 TIME
# Watson 119288 119294 PERSON
# Hosmer Angel 119356 119368 PERSON
# Hosmer Angel 119490 119502 PERSON
# five ft 119510 119517 QUANTITY
# seven 119519 119524 CARDINAL
# Albert 119790 119796 PERSON
# Harris 119813 119819 PERSON
# &c. 119967 119970 ORG
# Holmes 119993 119999 PERSON
# Angel 120118 120123 PERSON
# Balzac 120145 120151 PERSON
# one 120167 120170 CARDINAL
# Leadenhall Street 120428 120445 FAC
# two 120848 120851 CARDINAL
# One 120893 120896 CARDINAL
# Windibank 120972 120981 PERSON
# six o’clock 121027 121038 TIME
# evening 121049 121056 TIME
# Irene Adler 121635 121646 PERSON
# Four 121719 121723 CARDINAL
# the next evening 121976 121992 TIME
# Mary Sutherland 122121 122136 PERSON
# Baker Street 122403 122415 FAC
# half 122417 122421 CARDINAL
# Sherlock Holmes 122515 122530 PERSON
# half 122547 122551 CARDINAL
# yesterday 123059 123068 DATE
# Holmes 123310 123316 PERSON
# James Windibank 123461 123476 PERSON
# Holmes 123484 123490 PERSON
# six 123546 123549 CARDINAL
# some thirty
# years of age 123617 123641 DATE
# Good-evening 123919 123931 TIME
# James Windibank 123937 123952 PERSON
# Holmes 123960 123966 PERSON
# six o’clock 124064 124075 TIME
# Sutherland 124192 124202 PERSON
# Holmes 124784 124790 GPE
# Hosmer Angel 124871 124883 PERSON
# Windibank 124891 124900 PERSON
# Holmes 125019 125025 PERSON
# two 125139 125142 CARDINAL
# Windibank 125287 125296 PERSON
# fourteen 125418 125426 CARDINAL
# Holmes 125742 125748 PERSON
# these days 125813 125823 DATE
# four 125944 125948 CARDINAL
# fourteen 126166 126174 CARDINAL
# Windibank 126246 126255 PERSON
# Holmes 126362 126368 PERSON
# Holmes 126477 126483 PERSON
# Windibank 126608 126617 PERSON
# Holmes 126731 126737 PERSON
# Windibank 126792 126801 PERSON
# Holmes 127486 127492 PERSON
# a hundred a year 128253 128269 DATE
# Hosmer Angel 129017 129029 PERSON
# first 129107 129112 ORDINAL
# France 129347 129353 GPE
# Angel 129558 129563 PERSON
# France 129890 129896 GPE
# the very morning 130276 130292 TIME
# James Windibank 130309 130324 PERSON
# Sutherland 130337 130347 PERSON
# Hosmer Angel 130366 130378 PERSON
# ten years 130422 130431 DATE
# one 130635 130638 CARDINAL
# four 130649 130653 CARDINAL
# Windibank 130726 130735 PERSON
# Holmes 130798 130804 PERSON
# Holmes 130927 130933 PERSON
# first 131109 131114 ORDINAL
# Holmes 131276 131282 PERSON
# Jove 131473 131477 PERSON
# two 131687 131690 CARDINAL
# James Windibank 131861 131876 PERSON
# Holmes 131966 131972 PERSON
# first 132322 132327 ORDINAL
# Hosmer 132342 132348 PERSON
# two 132556 132559 CARDINAL
# Westhouse & Marbank 133795 133814 ORG
# Fenchurch Street 133819 133835 FAC
# James Windibank 133918 133933 PERSON
# Sutherland 133961 133971 PERSON
# Persian 134040 134047 NORP
# Hafiz 134194 134199 ORG
# Horace 134206 134212 GPE
# one morning 134317 134328 TIME
# Sherlock Holmes 134394 134409 FAC
# a couple of days 134442 134458 DATE
# England 134511 134518 GPE
# Boscombe Valley 134538 134553 GPE
# Sherlock Holmes 134983 134998 PERSON
# one 135077 135080 CARDINAL
# only half an hour 135155 135172 TIME
# Afghanistan 135206 135217 GPE
# Paddington Station 135404 135422 ORG
# gaunt 135487 135492 ORG
# Watson 135633 135639 PERSON
# two 135823 135826 CARDINAL
# Holmes 135943 135949 PERSON
# some days 136263 136272 DATE
# London 136281 136287 GPE
# Boscombe Valley 137081 137096 LOC
# Ross 137137 137141 PERSON
# John
# Turner 137213 137224 PERSON
# Australia 137248 137257 GPE
# some years ago 137271 137285 DATE
# One 137306 137309 CARDINAL
# Hatherley 137346 137355 LOC
# Charles McCarthy 137372 137388 PERSON
# colonies 137457 137465 GPE
# Turner 137581 137587 ORG
# McCarthy 137622 137630 PERSON
# McCarthy 137745 137753 PERSON
# one 137758 137761 CARDINAL
# eighteen 137776 137784 DATE
# Turner 137790 137796 ORG
# English 137933 137940 NORP
# McCarthys 137997 138006 PERSON
# McCarthy 138094 138102 PERSON
# two 138108 138111 CARDINAL
# Turner 138139 138145 ORG
# some half-dozen 138176 138191 CARDINAL
# June 3rd 138296 138304 DATE
# Monday 138318 138324 DATE
# McCarthy 138331 138339 PERSON
# Hatherley 138358 138367 PERSON
# about three 138368 138379 CARDINAL
# the Boscombe Valley 138515 138534 LOC
# Ross 138591 138595 PERSON
# three 138691 138696 CARDINAL
# the Boscombe Pool 138776 138793 FAC
# a quarter 138797 138806 CARDINAL
# two 138822 138825 CARDINAL
# One 138872 138875 CARDINAL
# William Crowder 138941 138956 PERSON
# Turner 138993 138999 PERSON
# McCarthy 139038 139046 PERSON
# a
# few minutes 139099 139112 TIME
# McCarthy 139131 139139 PERSON
# James McCarthy 139170 139184 PERSON
# two 139438 139441 CARDINAL
# McCarthys 139442 139451 ORG
# William Crowder 139482 139497 PERSON
# The Boscombe Pool 139536 139553 ORG
# fourteen 139646 139654 CARDINAL
# Patience Moran 139656 139670 PERSON
# Boscombe Valley 139719 139734 GPE
# McCarthy 139882 139890 PERSON
# McCarthy 139973 139981 PERSON
# two 140222 140225 CARDINAL
# McCarthys 140226 140235 PERSON
# Boscombe Pool 140253 140266 GPE
# McCarthy 140368 140376 PERSON
# Tuesday 141102 141109 DATE
# Wednesday 141121 141130 DATE
# Ross 141165 141169 PERSON
# Assizes 141210 141217 ORG
# Holmes 141507 141513 PERSON
# one 141567 141570 CARDINAL
# Turner 141945 141951 PERSON
# Lestrade 142049 142057 PERSON
# Lestrade 142161 142169 PERSON
# two 142243 142246 CARDINAL
# fifty miles an hour 142292 142311 QUANTITY
# Lestrade 142676 142684 PERSON
# first 142885 142890 ORDINAL
# Lestrade 143024 143032 PERSON
# every morning 143205 143218 TIME
# this season 143227 143238 DATE
# one 143827 143830 CARDINAL
# two 143834 143837 CARDINAL
# Hatherley Farm 144023 144037 ORG
# Holmes 144565 144571 PERSON
# one 145953 145956 CARDINAL
# two 145960 145963 CARDINAL
# Herefordshire 146104 146117 PERSON
# James McCarthy 146378 146392 PERSON
# three days 146501 146511 DATE
# the morning of last Monday 146556 146582 TIME
# Ross 146709 146713 PERSON
# John
# Cobb 146719 146728 PERSON
# William Crowder 147118 147133 PERSON
# about a hundred yards 147296 147317 QUANTITY
# Hatherley Farm 147771 147785 ORG
# more than 150 yards 147802 147821 QUANTITY
# some minutes 148082 148094 TIME
# Turner 148124 148130 PERSON
# The Coroner: Did your father 148459 148487 WORK_OF_ART
# The Coroner: 148614 148626 WORK_OF_ART
# The Coroner: 148736 148748 WORK_OF_ART
# The Coroner: I am afraid 148867 148891 WORK_OF_ART
# The Coroner: That 149051 149068 WORK_OF_ART
# The Coroner: 149268 149280 WORK_OF_ART
# The Coroner: How 149388 149404 WORK_OF_ART
# Bristol 149508 149515 ORG
# A Juryman: Did 149575 149589 WORK_OF_ART
# The Coroner: 149743 149755 WORK_OF_ART
# A dozen yards 150348 150361 QUANTITY
# a dozen yards 150488 150501 QUANTITY
# McCarthy 150718 150726 PERSON
# Holmes 151029 151035 PERSON
# Swindon 151875 151882 ORG
# twenty
# minutes 151920 151934 TIME
# Stroud Valley 152018 152031 LOC
# Severn 152061 152067 NORP
# Ross 152122 152126 PERSON
# Lestrade 152364 152372 PERSON
# Scotland Yard 152377 152390 ORG
# the Hereford Arms 152413 152430 ORG
# Lestrade 152512 152520 PERSON
# Lestrade 152776 152784 PERSON
# Twenty-nine 152856 152867 CARDINAL
# Lestrade 153121 153129 PERSON
# Sherlock Holmes 153903 153918 PERSON
# James 154125 154130 PERSON
# Turner 154486 154492 PERSON
# Sherlock Holmes 154500 154515 PERSON
# Lestrade 154829 154837 ORG
# Lestrade 154871 154879 PERSON
# James 155045 155050 PERSON
# Holmes 155235 155241 PERSON
# James 155284 155289 PERSON
# McCarthy 155342 155350 PERSON
# James 155412 155417 PERSON
# one 155659 155662 CARDINAL
# Holmes 155699 155705 PERSON
# McCarthy 155790 155798 PERSON
# Holmes 155871 155877 GPE
# years
# back 156139 156149 DATE
# Willows 156225 156232 PERSON
# McCarthy 156303 156311 PERSON
# Victoria 156372 156380 GPE
# Victoria 156392 156400 GPE
# Turner 156503 156509 PERSON
# Turner 156564 156570 PERSON
# James 156710 156715 PERSON
# Holmes 156736 156742 PERSON
# Turner 156804 156810 PERSON
# Holmes 157093 157099 PERSON
# Lestrade 157107 157115 PERSON
# James McCarthy 157318 157332 PERSON
# Holmes 157340 157346 PERSON
# Hereford 157518 157526 PERSON
# Watson 157581 157587 PERSON
# a couple of hours 157654 157671 TIME
# the day 158180 158187 DATE
# weekly 158649 158655 DATE
# third 158782 158787 ORDINAL
# half 158827 158831 CARDINAL
# McCarthy 159660 159668 PERSON
# dozen 159914 159919 CARDINAL
# Lestrade 160019 160027 ORG
# Sherlock Holmes 160070 160085 FAC
# McCarthy 160195 160203 PERSON
# Sherlock Holmes 160237 160252 FAC
# Lestrade 160287 160295 PERSON
# McCarthy 160653 160661 PERSON
# some two years ago 161261 161279 DATE
# five years 161358 161368 DATE
# Bristol 161456 161463 ORG
# the last three days 162093 162112 DATE
# Bristol 162116 162123 ORG
# the Bermuda Dockyard 162429 162449 ORG
# McCarthy 162545 162553 PERSON
# two 162688 162691 CARDINAL
# second 162892 162898 ORDINAL
# George Meredith 163076 163091 PERSON
# Holmes 163186 163192 PERSON
# nine o’clock 163254 163266 TIME
# Lestrade 163267 163275 PERSON
# Hatherley Farm 163328 163342 ORG
# the Boscombe Pool 163347 163364 GPE
# this morning 163390 163402 TIME
# Lestrade 163405 163413 PERSON
# Turner 163445 163451 PERSON
# Hall 163460 163464 PERSON
# Holmes 163543 163549 PERSON
# About sixty 163553 163564 CARDINAL
# McCarthy’s 163749 163759 ORG
# Hatherley Farm 163840 163854 ORG
# Holmes 163904 163910 PERSON
# a hundred 163926 163935 CARDINAL
# McCarthy 164083 164091 PERSON
# Turner 164179 164185 ORG
# Turner 164228 164234 ORG
# Turner 164443 164449 ORG
# Lestrade 164610 164618 PERSON
# Holmes 164675 164681 GPE
# Holmes 164755 164761 PERSON
# Lestrade 164915 164923 PERSON
# McCarthy 164965 164973 PERSON
# McCarthy 165000 165008 PERSON
# Holmes 165135 165141 PERSON
# Hatherley Farm 165197 165211 ORG
# two 165299 165302 CARDINAL
# Holmes’
#  165565 165573 ORG
# seven 165765 165770 CARDINAL
# eight 165774 165779 CARDINAL
# Holmes 165798 165804 PERSON
# Boscombe Pool 165900 165913 PERSON
# Baker
# Street 166048 166060 ORG
# two 166154 166157 CARDINAL
# the Boscombe Pool 166753 166770 FAC
# Lestrade 167047 167055 PERSON
# The Boscombe Pool 167270 167287 WORK_OF_ART
# Hatherley
# Farm 167397 167411 ORG
# Turner 167452 167458 PERSON
# Hatherley 167616 167625 ORG
# twenty 167714 167720 CARDINAL
# Lestrade 167800 167808 PERSON
# Holmes 167998 168004 PERSON
# six or eight feet 168730 168747 TIME
# three 168777 168782 CARDINAL
# McCarthy 168961 168969 PERSON
# Holmes
#  169678 169685 PERSON
# Moran 170437 170442 ORG
# about ten minutes 170599 170616 TIME
# Ross 170664 170668 PERSON
# Holmes 170670 170676 GPE
# Lestrade 170772 170780 PERSON
# a few days 170964 170974 DATE
# Indian 171239 171245 NORP
# Lestrade 171408 171416 PERSON
# British 171544 171551 NORP
# Holmes 171587 171593 PERSON
# this afternoon 171668 171682 TIME
# London 171713 171719 GPE
# evening 171727 171734 TIME
# Lestrade 172003 172011 PERSON
# Scotland Yard 172215 172228 ORG
# Holmes 172250 172256 PERSON
# Lestrade 172384 172392 PERSON
# Watson 172611 172617 PERSON
# two 172885 172888 CARDINAL
# McCarthy 172908 172916 PERSON
# One 173023 173026 CARDINAL
# Bristol 173520 173527 GPE
# Australian 173704 173714 NORP
# Australians 173750 173761 NORP
# McCarthy 173814 173822 PERSON
# Boscombe Pool 173847 173860 ORG
# Australia 173889 173898 GPE
# Sherlock Holmes 173928 173943 PERSON
# the Colony of Victoria 174033 174055 WORK_OF_ART
# Bristol 174079 174086 ORG
# last night 174094 174104 TIME
# ARAT 174167 174171 WORK_OF_ART
# BALLARAT 174216 174224 PRODUCT
# Ballarat 174394 174402 NORP
# third 174556 174561 ORDINAL
# Ballarat 174724 174732 NORP
# to-day 174958 174964 DATE
# Lestrade 175058 175066 PERSON
# Indian 176001 176007 NORP
# 140 176115 176118 CARDINAL
# Indian 176294 176300 NORP
# Rotterdam 176343 176352 GPE
# John Turner 176825 176836 PERSON
# craggy 177095 177101 PERSON
# Holmes 177586 177592 PERSON
# Hall 177765 177769 PERSON
# Holmes 177930 177936 PERSON
# McCarthy 178008 178016 PERSON
# Assizes 178217 178224 ORG
# Holmes 178265 178271 PERSON
# Holmes 178459 178465 PERSON
# McCarthy 178612 178620 PERSON
# Turner 178678 178684 ORG
# years 178711 178716 DATE
# Holmes 178839 178845 PERSON
# jot 178980 178983 PERSON
# Watson 179022 179028 PERSON
# McCarthy 179123 179131 PERSON
# Assizes 179284 179291 ORG
# McCarthy 179516 179524 PERSON
# these twenty years 179649 179667 DATE
# six 180047 180050 CARDINAL
# Black Jack 180187 180197 PERSON
# Ballarat 180201 180209 NORP
# the Ballarat Gang 180288 180305 GPE
# One day 180309 180316 DATE
# Ballarat 180346 180354 NORP
# Melbourne 180358 180367 GPE
# six 180423 180426 CARDINAL
# six 180440 180443 CARDINAL
# four 180491 180495 CARDINAL
# Three 180534 180539 CARDINAL
# McCarthy 180669 180677 PERSON
# England 180905 180912 GPE
# Alice 181264 181269 PERSON
# McCarthy 181484 181492 PERSON
# Jack 181662 181666 PERSON
# don’t 181817 181822 CARDINAL
# England 181859 181866 GPE
# Alice 182193 182198 ORG
# Alice 182456 182461 ORG
# McCarthy 182812 182820 PERSON
# Holmes 183654 183660 PERSON
# Holmes 184206 184212 PERSON
# Assizes 184518 184525 ORG
# McCarthy 184563 184571 PERSON
# Holmes 184994 185000 PERSON
# Baxter’s 185141 185149 ORG
# Sherlock Holmes 185205 185220 PERSON
# James McCarthy 185225 185239 PERSON
# Assizes 185261 185268 ORG
# Holmes 185339 185345 PERSON
# Turner 185390 185396 ORG
# seven months 185407 185419 DATE
# FIVE 185621 185625 CARDINAL
# ORANGE PIPS 185626 185637 ORG
# between the years ’82 185709 185730 DATE
# one 186420 186423 CARDINAL
# the Amateur Mendicant Society 186915 186944 ORG
# British 187061 187068 NORP
# Sophy Anderson 187077 187091 PERSON
# the Grice Patersons 187124 187143 ORG
# Uffa 187161 187165 GPE
# Camberwell 187186 187196 NORP
# Sherlock Holmes 187250 187265 PERSON
# two hours 187347 187356 TIME
# the latter days of September 187695 187723 DATE
# London 187915 187921 GPE
# evening 188155 188162 TIME
# one 188296 188299 CARDINAL
# one 188392 188395 CARDINAL
# Clark Russell’s 188399 188414 PERSON
# a few days 188632 188642 DATE
# Baker Street 188691 188703 FAC
# such an hour 189016 189028 TIME
# Sherlock Holmes 189105 189120 PERSON
# Holmes 190078 190084 PERSON
# Horsham 190203 190210 GPE
# Holmes 190418 190424 PERSON
# Tankerville Club 190482 190498 ORG
# four 190689 190693 CARDINAL
# three 190700 190705 CARDINAL
# Holmes 191311 191317 PERSON
# John Openshaw 191577 191590 PERSON
# two 191847 191850 CARDINAL
# Elias 191865 191870 PERSON
# Joseph 191885 191891 PERSON
# Coventry 191926 191934 ORG
# Openshaw 192022 192030 ORG
# Elias 192169 192174 PERSON
# America 192188 192195 GPE
# Florida 192244 192251 GPE
# Jackson’s 192335 192344 ORG
# Lee 192414 192417 PERSON
# three 192496 192501 CARDINAL
# four
# years 192505 192515 DATE
# About 1869 or 1870 192517 192535 CARDINAL
# Europe 192552 192558 LOC
# Sussex 192586 192592 GPE
# Horsham 192599 192606 GPE
# States 192655 192661 GPE
# Republican 192751 192761 NORP
# all the years 192935 192948 DATE
# Horsham 192966 192973 GPE
# two or three 193036 193048 CARDINAL
# weeks 193133 193138 DATE
# twelve 193429 193435 CARDINAL
# the year 1878 193460 193473 DATE
# eight or nine years 193493 193512 DATE
# England 193516 193523 GPE
# one 193978 193981 CARDINAL
# One day 194347 194354 DATE
# March 194365 194370 DATE
# 1883 194372 194376 DATE
# India 194598 194603 GPE
# five 194713 194717 CARDINAL
# K. K. K. 195020 195028 PERSON
# ‘Death 195133 195139 WORK_OF_ART
# three 195342 195347 CARDINAL
# five 195396 195400 CARDINAL
# one 195609 195612 CARDINAL
# Fordham 195829 195836 ORG
# Horsham 195842 195849 GPE
# John 196265 196269 PERSON
# two 196609 196612 CARDINAL
# Fordham 196710 196717 PERSON
# the weeks 197095 197104 DATE
# Holmes 198024 198030 PERSON
# two feet 198342 198350 QUANTITY
# some £ 14,000 198677 198690 MONEY
# One 198732 198735 CARDINAL
# Holmes 198745 198751 PERSON
# one 198795 198798 CARDINAL
# March 10, 1883 198983 198997 DATE
# seven weeks later 199013 199030 DATE
# the night of May 2nd 199037 199057 TIME
# Horsham 199119 199126 PERSON
# K. K.
# K. 199369 199377 PERSON
# Openshaw 199554 199562 PERSON
# America 199710 199717 GPE
# Southern 199895 199903 NORP
# North 200065 200070 LOC
# January 200199 200206 DATE
# the fourth day 200218 200232 DATE
# the new year 200239 200251 DATE
# five 200409 200413 CARDINAL
# John 200680 200684 PERSON
# K. K. K. 200739 200747 PERSON
# I. 200755 200757 ORG
# ‘Put the papers on the sundial 200881 200911 WORK_OF_ART
# ‘From Dundee 201260 201272 WORK_OF_ART
# the third day 201788 201801 DATE
# Freebody 201895 201903 PERSON
# one 201926 201929 CARDINAL
# Portsdown Hill 201948 201962 PERSON
# the second day 202113 202127 DATE
# over one 202232 202240 CARDINAL
# Fareham 202477 202484 GPE
# one 203305 203308 CARDINAL
# January 203342 203349 DATE
# two years
# and 203393 203406 DATE
# eight months 203407 203419 DATE
# Horsham 203486 203493 GPE
# yesterday 203663 203672 DATE
# morning 203673 203680 TIME
# five 203857 203861 CARDINAL
# London 203944 203950 GPE
# eastern 203951 203958 ORG
# K. K. K.’ 204038 204047 PERSON
# Holmes 204121 204127 PERSON
# Sherlock Holmes 204463 204478 PERSON
# two days 205390 205398 DATE
# one 205596 205599 CARDINAL
# John Openshaw 205613 205626 PERSON
# the day 205796 205803 DATE
# Holmes 206312 206318 PERSON
# March, 1869 206467 206478 DATE
# 4th 206535 206538 PRODUCT
# Hudson 206540 206546 PERSON
# 7th 206574 206577 ORDINAL
# McCauley 206595 206603 ORG
# Paramore 206605 206613 ORG
# John Swain 206619 206629 PERSON
# 9th 206650 206653 ORDINAL
# 10th 206675 206679 ORDINAL
# John Swain 206681 206691 PERSON
# Paramore 206717 206725 PERSON
# Holmes 206757 206763 PERSON
# one 207006 207009 CARDINAL
# only one 207259 207267 CARDINAL
# first 207649 207654 ORDINAL
# second 207727 207733 ORDINAL
# Waterloo 208169 208177 PERSON
# nine 208196 208200 CARDINAL
# Horsham 208416 208423 GPE
# London 208458 208464 GPE
# a day 208533 208538 DATE
# two days 208546 208554 DATE
# Watson 209218 209224 PERSON
# Four 209344 209348 CARDINAL
# John Openshaw 209398 209411 PERSON
# Sholtos 209476 209483 PERSON
# this K. K. K. 209664 209677 PERSON
# Sherlock Holmes 209725 209740 PERSON
# one 210199 210202 CARDINAL
# these
# days 210761 210771 DATE
# one 211043 211046 CARDINAL
# the early days 211060 211074 DATE
# zero 211250 211254 CARDINAL
# fifty miles 211351 211362 QUANTITY
# Holmes 211602 211608 PERSON
# American Encyclopædia 212044 212065 ORG
# first 212196 212201 ORDINAL
# Openshaw 212261 212269 PERSON
# America 212310 212317 GPE
# Florida 212421 212428 GPE
# English 212455 212462 LANGUAGE
# England 212512 212519 GPE
# America 212686 212693 GPE
# first 212891 212896 ORDINAL
# Pondicherry 212906 212917 GPE
# second 212923 212929 ORDINAL
# Dundee 212935 212941 GPE
# third 212951 212956 ORDINAL
# London 212962 212968 GPE
# seven weeks 213301 213312 DATE
# Dundee 213363 213369 GPE
# seven
# weeks 213965 213976 DATE
# those seven weeks 213999 214016 DATE
# Openshaw 214269 214277 ORG
# London 214420 214426 GPE
# Openshaw 214561 214569 ORG
# more than one 214708 214721 CARDINAL
# two 214771 214774 CARDINAL
# K. K. K. 215009 215017 PERSON
# Sherlock Holmes 215146 215161 PERSON
# the Ku Klux Klan 215226 215242 FAC
# Ku Klux Klan 215356 215368 PERSON
# Southern 215536 215544 NORP
# the
# Civil War 215558 215571 ORG
# Tennessee 215656 215665 GPE
# Louisiana 215667 215676 GPE
# Carolinas 215682 215691 GPE
# Georgia 215693 215700 GPE
# Florida 215706 215713 GPE
# some years 216561 216571 DATE
# United States 216631 216644 GPE
# South 216706 216711 LOC
# the year 1869 216728 216741 DATE
# Holmes 216888 216894 PERSON
# Openshaw 217005 217013 ORG
# America 217019 217026 GPE
# first 217258 217263 ORDINAL
# South 217275 217280 LOC
# night 217336 217341 TIME
# Openshaw 217793 217801 ORG
# half an hour 217965 217977 TIME
# Sherlock Holmes 218190 218205 PERSON
# first 218487 218492 ORDINAL
# Horsham 218529 218536 GPE
# first 218574 218579 ORDINAL
# Openshaw 219027 219035 ORG
# Waterloo Bridge 219067 219082 PERSON
# Between nine and ten 219109 219129 DATE
# Police-Constable Cook 219141 219162 ORG
# Waterloo Bridge 219196 219211 PERSON
# John Openshaw 219632 219645 PERSON
# Horsham 219675 219682 GPE
# Waterloo Station 219767 219783 GPE
# one 219879 219882 CARDINAL
# some minutes 220215 220227 TIME
# Holmes 220229 220235 PERSON
# Watson 220311 220317 PERSON
# Embankment 220865 220875 NORP
# night 220972 220977 TIME
# Watson 221004 221010 PERSON
# evening 221264 221271 TIME
# Baker 221293 221298 PERSON
# Watson 221869 221875 PERSON
# five 222095 222099 CARDINAL
# James Calhoun 222234 222247 PERSON
# Lone Star 222257 222266 PERSON
# Savannah 222269 222277 GPE
# Georgia 222279 222286 GPE
# a sleepless night 222370 222387 TIME
# Openshaw 222440 222448 ORG
# Calhoun 222492 222499 PERSON
# first 222560 222565 ORDINAL
# Lloyd’s 222728 222735 ORG
# Pondicherry 222836 222847 GPE
# January and February 222851 222871 DATE
# thirty-six 222891 222901 CARDINAL
# those
# months 222957 222969 DATE
# Lone Star 222991 223000 PRODUCT
# one 223135 223138 CARDINAL
# the
# Union 223156 223165 ORG
# Texas 223170 223175 GPE
# American 223260 223268 NORP
# Dundee 223309 223315 ORG
# Lone 223359 223363 PERSON
# January 223383 223390 DATE
# London 223500 223506 GPE
# Lone Star 223524 223533 PRODUCT
# last week 223552 223561 DATE
# Albert 223582 223588 PERSON
# this morning 223661 223673 TIME
# Savannah 223693 223701 GPE
# Goodwins 223840 223848 PERSON
# two 223960 223963 CARDINAL
# Americans 224008 224017 NORP
# Finns 224046 224051 NORP
# Germans 224056 224063 NORP
# three 224098 224103 CARDINAL
# last
#  224123 224128 TIME
# night 224128 224133 TIME
# Savannah 224241 224249 PERSON
# Savannah 224342 224350 GPE
# three 224362 224367 CARDINAL
# John Openshaw 224512 224525 PERSON
# that year 224717 224726 DATE
# Lone Star 224760 224769 PRODUCT
# Atlantic 224860 224868 LOC
# VI 225063 225065 ORG
# Isa Whitney 225098 225109 PERSON
# Elias Whitney 225131 225144 PERSON
# D.D. 225146 225150 ORG
# De Quincey’s 225340 225352 PERSON
# many years
#  225583 225594 DATE
# One night 225842 225851 TIME
# June 225862 225866 DATE
# the
# hour 225908 225916 TIME
# first 225938 225943 ORDINAL
# a weary day 226180 226191 DATE
# Kate Whitney 226682 226694 PERSON
# Kate 226717 226721 PERSON
# James 227081 227086 PERSON
# Isa 227167 227170 ORG
# two days 227197 227205 DATE
# first 227254 227259 ORDINAL
# Hitherto 227695 227703 PERSON
# one
# day 227743 227750 DATE
# eight 227851 227856 CARDINAL
# the Bar of Gold 228034 228049 ORG
# Upper Swandam Lane 228054 228072 FAC
# one 228288 228291 CARDINAL
# second 228360 228366 ORDINAL
# Isa Whitney’s 228410 228423 ORG
# two hours 228590 228599 TIME
# ten minutes 228667 228678 TIME
# first 228930 228935 ORDINAL
# Upper Swandam Lane 228959 228977 PERSON
# London Bridge 229080 229093 FAC
# three 230382 230387 CARDINAL
# two 230470 230473 CARDINAL
# Malay 230559 230564 NORP
# I. 230711 230713 PERSON
# Isa Whitney 230751 230762 PERSON
# Whitney 230888 230895 PERSON
# Watson 231056 231062 PERSON
# Friday, June 19th 231124 231141 DATE
# Wednesday 231177 231186 DATE
# Wednesday 231194 231203 DATE
# Friday 231340 231346 DATE
# two
# days 231385 231393 DATE
# Watson 231472 231478 PERSON
# a few
# hours 231506 231517 TIME
# three 231519 231524 CARDINAL
# four 231532 231536 CARDINAL
# Kate 231609 231613 PERSON
# Kate 231626 231630 PERSON
# one 231682 231685 CARDINAL
# Watson 231764 231770 PERSON
# two 232468 232471 CARDINAL
# Sherlock Holmes 232816 232831 PERSON
# half 232917 232921 CARDINAL
# five minutes 233580 233592 TIME
# Sherlock Holmes 233630 233645 FAC
# Whitney 233780 233787 PERSON
# a few minutes 234035 234048 TIME
# Whitney’s 234077 234086 ORG
# Sherlock Holmes 234269 234284 PERSON
# two 234290 234293 CARDINAL
# Watson 234472 234478 PERSON
# one 234817 234820 CARDINAL
# Briefly 234878 234885 GPE
# Watson 234887 234893 PERSON
# hour 235116 235120 TIME
# Lascar 235201 235207 PERSON
# Paul’s Wharf 235327 235339 ORG
# nights 235425 235431 TIME
# Watson 235481 235487 GPE
# Neville St. Clair 235658 235675 ORG
# two 235756 235759 CARDINAL
# Watson 235959 235965 PERSON
# Holmes 235973 235979 PERSON
# two 236042 236045 CARDINAL
# Cedars 236246 236252 PERSON
# St. 236312 236315 PERSON
# Near Lee 236404 236412 WORK_OF_ART
# seven-mile 236433 236443 QUANTITY
# John 236573 236577 PERSON
# ’s half 236606 236613 CARDINAL
# about eleven 236650 236662 CARDINAL
# two 237204 237207 CARDINAL
# several miles 237564 237577 QUANTITY
# Watson 237834 237840 PERSON
# Lee 238232 238235 PERSON
# Watson 238445 238451 PERSON
# Some years ago 238529 238543 DATE
# May, 1884 238563 238572 DATE
# Lee 238587 238590 PERSON
# Neville St. Clair 238604 238621 ORG
# 1887 238817 238821 DATE
# two 238884 238887 CARDINAL
# the
# morning 238992 239003 TIME
# 5:14 239022 239026 TIME
# Cannon Street 239032 239045 LOC
# every night 239046 239057 TIME
# St. 239063 239066 PERSON
# thirty-seven years of age 239080 239105 DATE
# 10_s 239340 239344 DATE
# 220 239363 239366 MONEY
# Counties Bank 239409 239422 ORG
# Last Monday 239520 239531 DATE
# Neville 239536 239543 PERSON
# two 239636 239639 CARDINAL
# this same Monday 239796 239812 DATE
# the Aberdeen Shipping Company 239971 240000 ORG
# London 240034 240040 GPE
# Fresno Street 240093 240106 FAC
# Upper Swandam
# Lane 240130 240148 ORG
# St. Clair 240184 240193 PERSON
# 4:35 240330 240334 TIME
# Swandam Lane 240351 240363 PERSON
# Monday 240466 240472 DATE
# St. 240510 240513 PERSON
# Swandam Lane 240684 240696 PERSON
# second 240849 240855 ORDINAL
# One 241149 241152 CARDINAL
# first 241558 241563 ORDINAL
# Lascar 241620 241626 PERSON
# Fresno Street 241871 241884 WORK_OF_ART
# two 241977 241980 CARDINAL
# St. Clair 242112 242121 PERSON
# Lascar 242333 242339 PERSON
# St. Clair 242526 242535 PERSON
# one 243080 243083 CARDINAL
# at least four 243218 243231 CARDINAL
# Neville St. Clair 243538 243555 PERSON
# Neville 243748 243755 PERSON
# Lascar 244110 244116 PERSON
# St. 244182 244185 PERSON
# a very few seconds 244259 244277 TIME
# Hugh Boone 244489 244499 ORG
# Lascar 244625 244631 PERSON
# second 244689 244695 ORDINAL
# Neville St. Clair 244786 244803 ORG
# Hugh
# Boone 244817 244827 ORG
# ...
# Stars and Stripes 454054 454071 WORK_OF_ART
# Holmes 454124 454130 PERSON
# first 454258 454263 ORDINAL
# Lestrade 454458 454466 PERSON
# Scotland 454470 454478 GPE
# first 454545 454550 ORDINAL
# two 454552 454555 CARDINAL
# a few minutes 454710 454723 TIME
# the morning 454783 454794 TIME
# America 455034 455041 GPE
# American 455358 455366 NORP
# American 455388 455396 NORP
# Lestrade 456259 456267 PERSON
# a week 456450 456456 DATE
# one 456484 456487 CARDINAL
# London 456507 456513 GPE
# Eight 456581 456586 CARDINAL
# one 456655 456658 CARDINAL
# London 456711 456717 GPE
# second 456752 456758 ORDINAL
# Northumberland Avenue 456782 456803 FAC
# Francis H. Moulton 456849 456867 PERSON
# American 456872 456880 NORP
# Gordon Square 457074 457087 PERSON
# Ah, Watson 457578 457588 WORK_OF_ART
# Holmes 457596 457602 PERSON
# THE ADVENTURE OF THE BERYL 458065 458091 ORG
# one morning 458130 458141 TIME
# February 458445 458453 DATE
# morning 458454 458461 TIME
# the day 458479 458486 DATE
# Baker Street 458584 458596 FAC
# the Metropolitan Station 458924 458948 ORG
# about fifty 459058 459069 CARDINAL
# Holmes 459780 459786 PERSON
# bell 460025 460029 ORG
# A few moments later 460082 460101 TIME
# a minute 461028 461036 TIME
# Holmes 461292 461298 PERSON
# two 461558 461561 CARDINAL
# Holmes 461806 461812 PERSON
# Alexander Holder 461976 461992 PERSON
# Holder & Stevenson 462017 462035 ORG
# second 462142 462148 ORDINAL
# the City of London 462184 462202 GPE
# London 462277 462283 GPE
# Baker Street 462558 462570 FAC
# Underground 462578 462589 FAC
# One 463073 463076 CARDINAL
# the last few years 463238 463256 DATE
# Yesterday morning 463388 463405 TIME
# England 463736 463743 GPE
# Holder 463943 463949 PERSON
# 50,000 464159 464165 MONEY
# ten 464220 464223 CARDINAL
# one 464410 464413 CARDINAL
# morocco 465145 465152 GPE
# the Beryl Coronet 465223 465240 FAC
# One 465246 465249 CARDINAL
# I. 465311 465313 ORG
# thirty-nine 465471 465482 CARDINAL
# four days 466041 466050 DATE
# Holder 466158 466164 PERSON
# Monday 466794 466800 DATE
# morning 466801 466808 TIME
# fifty £ 1000 466927 466939 MONEY
# evening 467467 467474 TIME
# the next few days 467750 467767 DATE
# Streatham 467943 467952 ORG
# Holmes 468127 468133 PERSON
# three 468275 468280 CARDINAL
# Lucy Parr 468401 468410 PERSON
# second 468416 468422 ORDINAL
# a few months 468465 468477 DATE
# Arthur 468917 468923 PERSON
# Holmes 468965 468971 PERSON
# George Burnwell 470112 470127 PERSON
# George Burnwell 470221 470236 PERSON
# Arthur 470418 470424 PERSON
# Mary 470823 470827 PERSON
# five years ago 470964 470978 DATE
# only one 471294 471302 CARDINAL
# Holmes 471655 471661 PERSON
# night 471807 471812 TIME
# Arthur 471834 471840 GPE
# Mary 471845 471849 PERSON
# Lucy Parr 471963 471972 PERSON
# Mary 472081 472085 PERSON
# Arthur 472090 472096 PERSON
# Arthur 472232 472238 PERSON
# ‘Well 472264 472269 WORK_OF_ART
# night 472328 472333 TIME
# ‘Look here 472659 472669 WORK_OF_ART
# 200 472733 472736 MONEY
# third 473243 473248 ORDINAL
# the month 473263 473272 DATE
# Mary 473672 473676 PERSON
# Lucy 473846 473850 PERSON
# Holmes 474355 474361 PERSON
# About two 474733 474742 CARDINAL
# the morning 474746 474757 TIME
# half 475262 475266 CARDINAL
# One 475588 475591 CARDINAL
# three 475618 475623 CARDINAL
# three 475972 475977 CARDINAL
# half 476410 476414 CARDINAL
# first 476767 476772 ORDINAL
# Arthur’s 476835 476843 ORG
# Arthur 477072 477078 GPE
# five minutes 477524 477536 TIME
# I. 477625 477627 ORG
# three 477948 477953 CARDINAL
# one 478415 478418 CARDINAL
# This morning 478752 478764 TIME
# one night 479177 479186 TIME
# Sherlock Holmes 479350 479365 PERSON
# some few minutes 479381 479397 TIME
# Arthur 479565 479571 PERSON
# George Burnwell 479579 479594 PERSON
# one 479629 479632 CARDINAL
# Arthur 479685 479691 PERSON
# four-and-twenty 479860 479875 DATE
# Terrible 479955 479963 WORK_OF_ART
# I. 479996 479998 ORG
# Arthur’s 480793 480801 ORG
# Holmes 481254 481260 PERSON
# first 481379 481384 ORDINAL
# three 481746 481751 CARDINAL
# thirty-nine 481768 481779 CARDINAL
# thirty-six 481857 481867 CARDINAL
# Holmes 482174 482180 PERSON
# Holder 482210 482216 PERSON
# Streatham 482238 482247 PERSON
# an hour 482269 482276 TIME
# Holmes 482654 482660 GPE
# Fairbank 483192 483200 ORG
# Fairbank 483248 483256 PERSON
# two 483416 483419 CARDINAL
# two 483547 483550 CARDINAL
# Holmes 483792 483798 PERSON
# Holder 483992 483998 PERSON
# the morning 484552 484563 TIME
# Arthur 484842 484848 GPE
# Arthur 485517 485523 GPE
# Arthur 485621 485627 PERSON
# London 485743 485749 GPE
# Arthur 486126 486132 PERSON
# Holmes 486246 486252 PERSON
# Mary Holder 486358 486369 PERSON
# two 486401 486404 CARDINAL
# last night 486502 486512 TIME
# this morning 486721 486733 TIME
# last night 486824 486834 TIME
# two 487072 487075 CARDINAL
# Arthur 487223 487229 PERSON
# Holder 487283 487289 PERSON
# Francis Prosper 487621 487636 PERSON
# Holmes 487657 487663 PERSON
# Holmes 488006 488012 GPE
# one 488253 488256 CARDINAL
# first 488642 488647 ORDINAL
# Sherlock Holmes 488860 488875 PERSON
# thirty-six 489195 489205 CARDINAL
# one 489255 489258 CARDINAL
# three 489322 489327 CARDINAL
# Holder 489364 489370 PERSON
# Holmes 489378 489384 PERSON
# Holder 489888 489894 PERSON
# a few yards 489984 489995 QUANTITY
# Holder 490544 490550 PERSON
# an hour 490725 490732 TIME
# Holder 490907 490913 PERSON
# Holmes 490994 491000 PERSON
# last night 491257 491267 TIME
# Baker 491302 491307 PERSON
# morning 491331 491338 TIME
# between nine and ten 491339 491359 DATE
# evening 491756 491763 TIME
# three 492110 492115 CARDINAL
# a few minutes 492212 492225 TIME
# Watson 492506 492512 PERSON
# a few hours 492687 492698 TIME
# two 492781 492784 CARDINAL
# Streatham 493367 493376 PERSON
# midnight 493991 493999 TIME
# nights 494120 494126 TIME
# what hour 494225 494234 TIME
# Watson 494445 494451 PERSON
# this morning 494529 494541 TIME
# nine now 494563 494571 DATE
# Only two days ago 495152 495169 DATE
# One 495280 495283 CARDINAL
# Mary 495340 495344 PERSON
# this morning 495396 495408 TIME
# last
# night 495513 495523 TIME
# Holmes 496271 496277 PERSON
# Holder 496401 496407 PERSON
# Holmes 496505 496511 PERSON
# 1000 496586 496590 MONEY
# ten 496640 496643 CARDINAL
# Three thousand 496675 496689 CARDINAL
# Holmes 496885 496891 PERSON
# three 496965 496970 CARDINAL
# one 497239 497242 CARDINAL
# Holder 497268 497274 PERSON
# Sherlock Holmes 497282 497297 PERSON
# Arthur 497600 497606 PERSON
# yesterday 497636 497645 DATE
# morning 498063 498070 TIME
# first 498266 498271 ORDINAL
# George
# Burnwell 498377 498392 PERSON
# England 498672 498679 GPE
# a hundred 498855 498864 CARDINAL
# nearly every evening 499040 499060 TIME
# ashen
# face 499129 499139 ORG
# last night 499194 499204 TIME
# Arthur 499934 499940 GPE
# moonlight 501337 501346 WORK_OF_ART
# George Burnwell 501352 501367 PERSON
# Arthur 501391 501397 PERSON
# one 501469 501472 CARDINAL
# George 501561 501567 PERSON
# Holder 502326 502332 PERSON
# five minutes 502421 502433 TIME
# Holmes 502598 502604 PERSON
# the evening 502749 502760 TIME
# Wooden 503254 503260 GPE
# second 503719 503725 ORDINAL
# first 503882 503887 ORDINAL
# Boots 504127 504132 PERSON
# a hundred
# yards 504217 504232 QUANTITY
# Boots 504268 504273 PERSON
# George Burnwell 506388 506403 PERSON
# Arthur 506576 506582 PERSON
# George 506829 506835 PERSON
# the night before 506937 506953 TIME
# six 506987 506990 CARDINAL
# Streatham 507087 507096 PERSON
# yesterday 507187 507196 DATE
# evening 507197 507204 TIME
# first 507534 507539 ORDINAL
# 1000 507887 507891 CARDINAL
# six hundred 508011 508022 CARDINAL
# three 508031 508036 CARDINAL
# 1000 508222 508226 MONEY
# day 508380 508383 DATE
# England 508417 508424 GPE
# Holmes 508892 508898 PERSON
# George Burnwell 508926 508941 PERSON
# XII 509065 509068 ORG
# THE ADVENTURE OF THE COPPER BEECHES 509070 509105 ORG
# Sherlock Holmes 509162 509177 PERSON
# Watson 509389 509395 PERSON
# mood—“you 510248 510257 CARDINAL
# a cold morning 511154 511168 TIME
# the early spring 511172 511188 DATE
# Baker Street 511268 511280 FAC
# china 511501 511506 GPE
# Sherlock Holmes 511558 511573 PERSON
# all the morning 511590 511605 TIME
# the King of Bohemia 512202 512221 ORG
# Mary Sutherland 512255 512270 PERSON
# the days 512877 512885 DATE
# this morning 513219 513231 TIME
# zero 513241 513245 CARDINAL
# DEAR MR 513396 513403 WORK_OF_ART
# HOLMES,—I 513405 513414 PERSON
# half-past ten 513569 513582 DATE
# VIOLET HUNTER 513653 513666 ORG
# half-past ten 513728 513741 DATE
# first 513939 513944 ORDINAL
# Hunter 514709 514715 PERSON
# Holmes 514793 514799 GPE
# five years 515048 515058 DATE
# Spence Munro 515097 515109 PERSON
# two months ago 515115 515129 DATE
# Halifax 515169 515176 GPE
# Nova Scotia 515181 515192 ORG
# one 515873 515876 CARDINAL
# last week 515994 516003 DATE
# Stoper 516071 516077 PERSON
# Spence Munro 516839 516851 PERSON
# I. 517145 517147 ORG
# French 517158 517164 NORP
# German 517175 517181 NORP
# three 517610 517615 CARDINAL
# 100 517673 517676 MONEY
# Holmes 517709 517715 PERSON
# two 518014 518017 CARDINAL
# half 518106 518110 CARDINAL
# I. 518554 518556 ORG
# five miles 518613 518623 QUANTITY
# Winchester 518643 518653 PRODUCT
# One 518814 518817 CARDINAL
# one 518824 518827 CARDINAL
# six years old 518852 518865 DATE
# Three 518949 518954 CARDINAL
# Holmes 520057 520063 PERSON
# I. 520285 520287 ORG
# madam 520519 520524 GPE
# ‘Ah 520648 520651 WORK_OF_ART
# Stoper 520799 520805 PERSON
# Hunter 521433 521439 PERSON
# Holmes 521521 521527 PERSON
# two 521605 521608 CARDINAL
# three 521612 521617 CARDINAL
# England 521889 521896 GPE
# 100 521911 521914 MONEY
# Next day 522047 522055 DATE
# the day 522114 522121 DATE
# ‘The Copper Beeches 522357 522376 WORK_OF_ART
# Winchester 522383 522393 GPE
# 30 a quarter 522694 522706 DATE
# 120 522713 522716 MONEY
# Alice 523095 523100 PERSON
# Philadelphia 523109 523121 GPE
# Holmes 523842 523848 PERSON
# Hunter 524028 524034 PERSON
# Holmes 524094 524100 PERSON
# Holmes 524287 524293 PERSON
# only one 524413 524421 CARDINAL
# Rucastle 524445 524453 PERSON
# Holmes 524890 524896 PERSON
# some months 525439 525450 DATE
# night 525728 525733 TIME
# Rucastle 525952 525960 PERSON
# Winchester 526017 526027 PRODUCT
# Holmes 526069 526075 PERSON
# Holmes 526323 526329 PERSON
# Holmes 526899 526905 PERSON
# half an
# hour 526945 526957 TIME
# late one night 527319 527333 TIME
# Holmes 527375 527381 PERSON
# one 527403 527406 CARDINAL
# all-night 527416 527425 TIME
# the
# morning 527617 527628 TIME
# Bradshaw 527748 527756 PERSON
# the Black Swan Hotel 527865 527885 ORG
# midday 527903 527909 TIME
# Holmes 528008 528014 PERSON
# half-past nine 528098 528112 DATE
# 11:30 528178 528183 TIME
# the
# morning 528314 528325 TIME
# eleven o’clock 528332 528346 TIME
# English 528397 528404 LANGUAGE
# Hampshire 528505 528514 GPE
# an ideal spring day 528581 528600 DATE
# Aldershot 528876 528885 ORG
# Baker Street 529097 529109 FAC
# Watson 529162 529168 PERSON
# Watson 529687 529693 PERSON
# London 529760 529766 GPE
# year 530532 530536 DATE
# Winchester 530635 530645 GPE
# five miles 530697 530707 QUANTITY
# seven 530986 530991 CARDINAL
# Hunter 531279 531285 PERSON
# The Black Swan 531301 531315 WORK_OF_ART
# Rucastle 531802 531810 PERSON
# three 531829 531834 CARDINAL
# this morning 531870 531882 TIME
# first 532064 532069 ORDINAL
# Rucastle 532165 532173 PERSON
# Rucastle 532420 532428 PERSON
# three 532718 532723 CARDINAL
# fourth 532742 532748 ORDINAL
# Southampton 532782 532793 GPE
# about a hundred yards 532822 532843 QUANTITY
# Southerton 532949 532959 GPE
# Holmes 533224 533230 PERSON
# Baker Street 533301 533313 FAC
# Rucastle 533320 533328 PERSON
# about seven years 533569 533586 DATE
# first 533642 533647 ORDINAL
# Philadelphia 533686 533698 GPE
# Rucastle 533704 533712 PERSON
# less than twenty 533866 533882 CARDINAL
# Rucastle 533988 533996 PERSON
# one 534274 534277 CARDINAL
# one 535063 535066 CARDINAL
# Holmes 535235 535241 PERSON
# one 535445 535448 CARDINAL
# only two 535566 535574 CARDINAL
# uncouth man 535638 535649 PERSON
# Rucastle 535787 535795 PERSON
# Rucastle 535905 535913 PERSON
# one 536076 536079 CARDINAL
# two days 536110 536118 DATE
# third 536189 536194 ORDINAL
# Rucastle 536201 536209 PERSON
# Hunter 536357 536363 PERSON
# Rucastle 536966 536974 PERSON
# three 537190 537195 CARDINAL
# Rucastle 537364 537372 PERSON
# Rucastle 537588 537596 PERSON
# an
# hour 537750 537757 TIME
# Rucastle 537769 537777 PERSON
# the day 537839 537846 DATE
# Two days later 537923 537937 DATE
# about ten minutes 538377 538394 TIME
# Holmes 538558 538564 PERSON
# first 538830 538835 ORDINAL
# first 539249 539254 ORDINAL
# second 539274 539280 ORDINAL
# Southampton 539347 539358 GPE
# Rucastle 539666 539674 PERSON
# Hunter 539970 539976 PERSON
# Hunter 540007 540013 PERSON
# ‘Dear me 540066 540074 WORK_OF_ART
# Rucastle 540349 540357 PERSON
# a week ago 540388 540398 DATE
# Holmes 540541 540547 PERSON
# the very first day 540748 540766 DATE
# Rucastle 540805 540813 PERSON
# ‘Look in 540988 540996 WORK_OF_ART
# Rucastle 541013 541021 PERSON
# two 541049 541052 CARDINAL
# two 541123 541126 CARDINAL
# Carlo 541286 541291 ORG
# Toller 541337 541343 ORG
# night 541666 541671 TIME
# two nights later 541749 541765 DATE
# moonlight night 541863 541878 TIME
# London 542550 542556 GPE
# One evening 542621 542632 TIME
# two 542816 542819 CARDINAL
# first 542886 542891 ORDINAL
# two 542892 542895 CARDINAL
# third 543001 543006 ORDINAL
# first 543144 543149 ORDINAL
# only one 543214 543222 CARDINAL
# two 543632 543635 CARDINAL
# Holmes 544027 544033 PERSON
# one 544110 544113 CARDINAL
# the quarters of the 544211 544230 DATE
# Tollers 544231 544238 ORG
# One day 544293 544300 DATE
# Rucastle 544346 544354 PERSON
# four 544889 544893 CARDINAL
# a
# row 544905 544910 DATE
# three 544912 544917 CARDINAL
# fourth 544956 544962 ORDINAL
# Rucastle 545077 545085 PERSON
# one 545402 545405 CARDINAL
# Holmes 545867 545873 PERSON
# only yesterday 546382 546396 DATE
# Rucastle 546452 546460 PERSON
# Toller 546467 546473 ORG
# yesterday 546652 546661 DATE
# evening 546662 546669 TIME
# Rucastle 546808 546816 PERSON
# three 547127 547132 CARDINAL
# first 547154 547159 ORDINAL
# third 547164 547169 ORDINAL
# two 547250 547253 CARDINAL
# evening 547323 547330 TIME
# one 547493 547496 CARDINAL
# Holmes 548177 548183 PERSON
# Rucastle 548410 548418 PERSON
# Holmes 549780 549786 PERSON
# about half a mile 550219 550236 QUANTITY
# Toller 550409 550415 ORG
# evening 550469 550476 TIME
# Winchester 550759 550769 PRODUCT
# this morning 550770 550782 TIME
# three o’clock 550810 550823 TIME
# Rucastle 550842 550850 PERSON
# Holmes 550987 550993 PERSON
# Holmes 551097 551103 PERSON
# Rucastle 551372 551380 PERSON
# Rucastles 551442 551451 GPE
# Hunter 551646 551652 PERSON
# one 551690 551693 CARDINAL
# seven o’clock 551849 551862 TIME
# I. 551878 551880 ORG
# Rucastles 551885 551894 ORG
# Toller 551926 551932 ORG
# Toller 551986 551992 PERSON
# Alice Rucastle 552466 552480 PERSON
# America 552532 552539 GPE
# Rucastle 553062 553070 PERSON
# Watson 553386 553392 PERSON
# first 553584 553589 ORDINAL
# Holmes 553920 553926 PERSON
# seven o’clock 554192 554205 TIME
# that hour 554210 554219 TIME
# Copper Beeches 554368 554382 WORK_OF_ART
# Hunter 554587 554593 PERSON
# Holmes 554668 554674 PERSON
# Holmes 554924 554930 PERSON
# Hunter 555151 555157 PERSON
# Holmes 555173 555179 PERSON
# Hunter 555424 555430 PERSON
# Watson 555475 555481 PERSON
# Holmes 555867 555873 PERSON
# Hunter 555905 555911 PERSON
# Hunter 556205 556211 PERSON
# Rucastles 556248 556257 GPE
# Watson 556451 556457 PERSON
# Hunter 556670 556676 PERSON
# Sherlock Holmes 556739 556754 PERSON
# Spies 556968 556973 ORG
# Hunter 557153 557159 PERSON
# I. 557189 557191 ORG
# Holmes 557230 557236 PERSON
# two days 557602 557610 DATE
# Quick 557612 557617 ORG
# Holmes 557650 557656 PERSON
# Toller 557713 557719 ORG
# Rucastle 557802 557810 GPE
# Toller 558165 558171 ORG
# Toller 558345 558351 PERSON
# Hunter 558365 558371 PERSON
# Rucastle 558390 558398 PERSON
# Holmes 558592 558598 PERSON
# Toller 558646 558652 PERSON
# one 559084 559087 CARDINAL
# Alice 559132 559137 PERSON
# Alice 559188 559193 PERSON
# Fowler 559360 559366 PERSON
# Alice 559419 559424 PERSON
# Rucastle 559569 559577 PERSON
# six weeks 559953 559962 DATE
# Holmes 560179 560185 PERSON
# Rucastle 560318 560326 PERSON
# Hunter 560414 560420 PERSON
# London 560431 560437 GPE
# Fowler 560497 560503 PERSON
# Fowler 560537 560543 PERSON
# Fowler 560759 560765 PERSON
# Toller 561081 561087 PERSON
# Holmes 561095 561101 PERSON
# Rucastle 561211 561219 PERSON
# Watson 561233 561239 PERSON
# Hunter 561270 561276 PERSON
# Winchester 561285 561295 PRODUCT
# Rucastle 561479 561487 PERSON
# the day 561798 561805 DATE
# Mauritius 561896 561905 ORG
# Violet 561918 561924 PERSON
# Hunter 561925 561931 PERSON
# Holmes 561943 561949 PERSON

# %% [markdown]
# For an alternate method, we can create a list that contains pairs of entity text and the tag applied to that text:

# %%
# Let's create a list of pairs (the_text_of_the_entity, the_tag_applied_to_that_entity) for all of the entities
list_of_named_entities_data=[(ent, ent.label_) for ent in spacy_document.ents]

# Let's look at just the first 10 entries in our list
print("List of the first 10 tagged entities:\n")
list_of_named_entities_data[:10]
# Out:
# List of the first 10 tagged entities:
# [(The Adventures of Sherlock Holmes, 'WORK_OF_ART'),
#  (Arthur Conan Doyle, 'ORG'),
#  (Bohemia, 'GPE'),
#  (The Red-Headed League, 'ORG'),
#  (Identity, 'ORG'),
#  (The Boscombe Valley Mystery, 'FAC'),
#  (Five, 'CARDINAL'),
#  (The Man, 'WORK_OF_ART'),
#  (The Adventure of the Blue Carbuncle
#      VIII,
#   'WORK_OF_ART'),
#  (The Adventure of the Speckled Band, 'WORK_OF_ART')]

# %% [markdown]
# ### Visualizing the tagged named entities
#
# spaCy has a built-in visualizer called the [displaCy entity visualizer](https://spacy.io/usage/visualizers#ent) which we can use to visualize all of these tagged entities within the full text of our document.

# %%
displacy.render(spacy_document, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Adventures of Sherlock Holmes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# </br></br>by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arthur Conan Doyle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br></br>Contents</br></br>   I.     A Scandal in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bohemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>   II.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Red-Headed League
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>   III.   A Case of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Identity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>   IV.
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Boscombe Valley Mystery
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# </br>   V.     The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Orange Pips</br>   VI.
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Man
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  with the Twisted Lip</br>   VII.
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Adventure of the Blue Carbuncle
#    VIII
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# .
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Adventure of the Speckled Band
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# </br>   IX.
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Adventure of the Engineer’s Thumb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     X.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Adventure of the Noble Bachelor
#    XI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# .
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Adventure of the Beryl Coronet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     XII
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Adventure of the Copper Beeches
#
#
#
#
# I. A SCANDAL IN BOHEMIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# </br></br></br>I.</br></br>To Sherlock Holmes she is always _the_ woman. I have seldom heard him</br>mention her under any other name. In his eyes she eclipses and</br>predominates the whole of her sex. It was not that he felt any emotion</br>akin to love for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irene Adler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . All emotions, and that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  particularly,</br>were abhorrent to his cold, precise but admirably balanced mind. He</br>was, I take it, the most perfect reasoning and observing machine that</br>the world has seen, but as a lover he would have placed himself in a</br>false position. He never spoke of the softer passions, save with a gibe</br>and a sneer. They were admirable things for the observer—excellent for</br>drawing the veil from men’s motives and actions. But for the trained</br>reasoner to admit such intrusions into his own delicate and finely</br>adjusted temperament was to introduce a distracting factor which might</br>throw a doubt upon all his mental results. Grit in a sensitive</br>instrument, or a crack in one of his own high-power lenses, would not</br>be more disturbing than a strong emotion in a nature such as his. And</br>yet there was but one woman to him, and that woman was the late
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Irene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Adler, of dubious and questionable memory.</br></br>I had seen little of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Holmes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  lately. My marriage had drif

# %% [markdown]
# ### Output an HTML file with our tagged text

# %%
# Let's save this visualization to an HTML file
html = displacy.render(spacy_document, style="ent", page=True, jupyter=False)
with open("sherlock_holmes_spacy_output.html", 'w+', encoding="utf-8") as fp:
        fp.write(html)
        fp.close()

# %% [markdown]
# ### Generate a list of place names from our `spaCy` document
#
# Here, we're going to look at place names as defined by the "GPE" (geo-political entities) tag.

# %%
print("Geopolitical place names according to spaCy:")
for named_entity in spacy_document.ents:
    if named_entity.label_ == "GPE": # Look at just the geopolitical entities, labeled "GPE"
        print(named_entity)
# Out:
# Geopolitical place names according to spaCy:
# Bohemia
# Holmes
# Holland
# Holmes
# London
# Europe
# Egria
# Bohemia
# Bohemia
# Holmes
# Hercules
# England
# Europe
# Europe
# Prague
# Warsaw
# New Jersey
# Prima
# Warsaw
# London
# London
# Regent Street
# Serpentine
# Holmes
# Holmes
# Arnsworth Castle
# England
# Esq
# Holmes
# China
# China
# China
# China
# Lebanon
# Pennsylvania
# U.S.A.
# London
# south
# London
# London
# Holmes
# Kensington
# Holmes
# London
# Scotland
# Cornwall
# Holmes
# London
# London
# Archie
# London
# Holland
# London
# Devonshire
# New Zealand
# France
# France
# France
# France
# England
# Hague
# Holmes
# France
# France
# Horace
# England
# Boscombe Valley
# Afghanistan
# London
# Boscombe Valley
# Australia
# Hatherley
# colonies
# the Boscombe Valley
# Boscombe Valley
# Boscombe Pool
# Stroud Valley
# Holmes
# Victoria
# Victoria
# the Boscombe Pool
# Holmes
# Holmes
# London
# Bristol
# Australia
# Rotterdam
# the Ballarat Gang
# Melbourne
# England
# England
# Uffa
# London
# Horsham
# America
# Florida
# Europe
# Sussex
# Horsham
# States
# Horsham
# England
# India
# Horsham
# America
# North
# Fareham
# Horsham
# London
# Horsham
# London
# America
# Florida
# England
# America
# Pondicherry
# Dundee
# London
# Dundee
# London
# Tennessee
# Louisiana
# Carolinas
# Georgia
# Florida
# United States
# South
# America
# South
# Horsham
# Horsham
# Waterloo Station
# Savannah
# Georgia
# Pondicherry
# Texas
# London
# Savannah
# Savannah
# Atlantic
# Briefly
# Watson
# Cannon Street
# London
# Middlesex
# madam
# madam
# Europe
# Lee
# Chesterfield
# London
# London
# Holmes
# Holmes
# Holmes
# Jove
# morocco
# Horner
# the Amoy River
# China
# Holmes
# Covent Garden
# Holborn
# Covent Garden Market
# Brixton Road—249
# Pentonville
# Covent Garden
# Holmes
# madam
# England
# England
# Berkshire
# England
# India
# England
# Crewe
# London
# Reading
# Holmes
# Holmes
# Scotland
# Holmes
# Holmes
# India
# India
# Paddington
# London
# Greenwich
# London
# Berkshire
# England
# Eyford
# Eyford
# south
# London
# England
# San Francisco
# Cal.
# U.S.A.
# Great Britain
# Atlantic
# California
# Petersfield
# San Francisco
# States
# Pacific
# England
# London
# London
# California
# America
# Flora Millar
# Holmes
# Holmes
# Aberdeen
# Munich
# woodcock
# Europe
# America
# Rockies
# Pa.
# Montana
# Arizona
# New Mexico
# London
# California
# England
# Paris
# Scotland
# America
# London
# London
# the City of London
# London
# England
# morocco
# Arthur
# Arthur
# Holmes
# Arthur
# Arthur
# London
# Holmes
# England
# Arthur
# Wooden
# England
# china
# Holmes
# Halifax
# madam
# England
# Winchester
# Philadelphia
# Hampshire
# London
# Winchester
# Southampton
# Southerton
# Philadelphia
# Southampton
# London
# Rucastles
# America
# Rucastles
# Rucastle
# London

# %%
print("Geopolitical place names according to spaCy:")
for named_entity in spacy_document.ents:
    if named_entity.label_ == "LOC": # Look at just the geopolitical entities, labeled "GPE"
        print(named_entity)
# Out:
# Geopolitical place names according to spaCy:
# Europe
# Europe
# Europe
# Regent Street
# Boscombe Valley
# Hatherley
# the Boscombe Valley
# Stroud Valley
# Europe
# North
# South
# South
# Atlantic
# Cannon Street
# Europe
# the Amoy River
# Covent Garden
# Covent Garden Market
# Covent Garden
# Atlantic
# Pacific
# Europe
# Rockies

# %% [markdown]
# ## Method 2: Using `BookNLP` for named entity recognition
#
# What if we wanted to use a different model, one trained with a differen machine learning algorithm for recognizing entities?
#
# David Bamman developed [a natural language processing pipeline just for book-length works in English called `BookNLP`](https://github.com/booknlp/booknlp). (Unlike `spaCy`, the BookNLP model is not currently available for other languages, though Bamman's team is developing "Multlingual BookNLP" for Spanish, German, Japanese and Russian).
#
#
#
# ### `BookNLP`'s model & data
#
# Bamman's `BookNLP` named entity recognition model uses similar pipeline as `spaCy` (and even uses the algorithm as `spaCy` for tagging parts of speech), but uses a different machine learning model for recognizing enities (the [BERT model](https://huggingface.co/docs/transformers/model_doc/bert#bert), developed by Google) and is trained on a different training dataset.
#
# From the `BookNLP` [description of the training datset](https://github.com/booknlp/booknlp#entity-annotations):
#
# >"For more, see: David Bamman, Sejal Popat and Sheng Shen, ["An Annotated Dataset of Literary Entities,"](https://people.ischool.berkeley.edu/~dbamman/pubs/pdf/naacl2019_literary_entities.pdf) NAACL 2019.
# The entity tagging model within BookNLP is trained on an annotated dataset of 968K tokens, including the public domain materials in [LitBank](https://github.com/dbamman/litbank) and a new dataset of ~500 contemporary books, including bestsellers, Pulitzer Prize winners, works by Black authors, global Anglophone books, and genre fiction (article forthcoming)."

# %% [markdown]
# > ### 💡 Reflection 💡 :
# Take a look at the `BookNLP` training dataset as described above, and Bamman's [LitBank](https://github.com/dbamman/litbank) GitHub repository.  How does this training dataset compare to the training dataset for the defaul `spaCy` model? How might that change the context we might use it in?

# %% [markdown]
# **[TYPE YOUR RESPONSE HERE]**

# %% [markdown]
# ###  What entities can `BookNLP`'s 'Named Entity Recognition' model detect?
# For a complete list of the six categories of entities that `BookNLP` tags, see here: https://github.com/booknlp/booknlp#entity-annotations

# %% [markdown]
# ### Install `BookNLP`

# %%
# !pip install booknlp

# %% [markdown]
# ### Import `BookNLP`, define parameters and filepaths
#
# Take a look at the way `BookNLP` describes its usage here: https://github.com/booknlp/booknlp#usage

# %%
# Import BookNLP
from booknlp.booknlp import BookNLP

# Define the model parameters
# We can choose between the "big" or "small model"
# Below we are only using the named entity recognition pipeline ("entity")
# But there are other options that we might use, like quotations, or "coreference" resoluation
model_params={
		"pipeline":"entity", 
		"model":"small"
	}
	
booknlp=BookNLP("en", model_params)

# Input file to process
input_file="../_datasets/texts/literature/Arthur-Conan-Doyle-The-Adventures-of-Sherlock-Holmes.txt"

# Output directory to store resulting files in
output_directory="sherlock_holmes/"

# File within this directory will be named ${book_id}.entities, ${book_id}.tokens, etc.
book_id="adventures_of_sherlock_holmes"
# Out:
# {'pipeline': 'entity', 'model': 'small'}
# --- startup: 4.997 seconds ---

# %% [markdown]
# ### Run BookNLP
#
# Click and run the cell below–– `booknlp.process(input_file, output_directory, book_id)` to run the NLP model.
#
# Because the `BookNLP` model is a fair bit bigger than the standard `spaCy`, it will tak 2-3minutes to run. Go get yourself a cup of tea or a cup of coffee in the meantime!

# %%
booknlp.process(input_file, output_directory, book_id)
# Out:
# --- spacy: 25.552 seconds ---
# --- entities: 97.942 seconds ---
# --- quotes: 0.164 seconds ---
# --- name coref: 0.610 seconds ---
# --- TOTAL (excl. startup): 127.606 seconds ---, 127661 words

# %% [markdown]
# ### Read in the BookNLP output files as a dataframe
#
# In the cell bellow we read in the `adventures_of_sherlock_holmes.entities` output from running the `BookNLP` model on *The Adventures of Sherlock Holmes* as a dataframe, so that we can work with the data about tagged entities in tabular format.

# %%
sherlock_holmes_entities_df = pd.read_csv("sherlock_holmes/adventures_of_sherlock_holmes.entities", delimiter="\t")
sherlock_holmes_entities_df
# Out:
#        COREF  start_token  end_token  prop  cat                         text
# 0        240            3          4  PROP  PER              Sherlock Holmes
# 1        241            6          8  PROP  PER           Arthur Conan Doyle
# 2          1           14         15  PROP  FAC                   Bohemia II
# 3         -1           17         22   NOM  FAC  The Red - Headed League III
# 4          2           35         39  PROP  VEH      The Five Orange Pips VI
# ...      ...          ...        ...   ...  ...                          ...
# 18063     -1       127638     127638  PRON  PER                          she
# 18064     -1       127644     127648   NOM  FAC  a private school at Walsall
# 18065    239       127648     127648  PROP  GPE                      Walsall
# 18066      0       127651     127651  PRON  PER                            I
# 18067     -1       127654     127654  PRON  PER                          she
#
# [18068 rows x 6 columns]

# %% [markdown]
# ### Generating a list of place names from our  `BookNLP` dataframe
#
# We've just created a `pandas` DataFrame-- so we can apply any of the `pandas` methods that we've learned to sort, filter, and analyze the dataframe.
#
# Below, we're going to fileter our dataframe to look for values in the "cat" column (ie, the NER labels) that are "GPE" (ie, geopolitical entities).

# %%
sherlock_holmes_entities_df[sherlock_holmes_entities_df['cat'] == 'GPE']
# Out:
#        COREF  start_token  end_token  prop  cat  \
# 9          4           99         99  PROP  GPE
# 62         6          509        509  PROP  GPE
# 65         7          531        531  PROP  GPE
# 68         8          551        551  PROP  GPE
# 83         9          657        657  PROP  GPE
# 174       10         1214       1214  PROP  GPE
# 229       11         1638       1638  PROP  GPE
# 264       -1         2025       2029   NOM  GPE
# 265        4         2032       2032  PROP  GPE
# 266       12         2037       2037  PROP  GPE
# 267       13         2049       2049  PROP  GPE
# 274        4         2102       2102  PROP  GPE
# 316       14         2469       2469  PROP  GPE
# 394       11         3035       3035  PROP  GPE
# 396       15         3048       3048  PROP  GPE
# 398        4         3053       3053  PROP  GPE
# 409       11         3113       3113  PROP  GPE
# 436       16         3246       3251  PROP  GPE
# 438        4         3257       3257  PROP  GPE
# 453       17         3333       3333  PROP  GPE
# 457       18         3375       3375  PROP  GPE
# 477       19         3507       3508  PROP  GPE
# 480       18         3528       3528  PROP  GPE
# 481       10         3541       3541  PROP  GPE
# 529       21         3930       3930  PROP  GPE
# 559       10         4153       4153  PROP  GPE
# 562       22         4167       4168  PROP  GPE
# 573       -1         4237       4243   NOM  GPE
# 574       -1         4239       4243   NOM  GPE
# 794       28         5826       5827  PROP  GPE
# 810       28         5910       5911  PROP  GPE
# 1180      29         8504       8504  PROP  GPE
# 1236      31         8875       8876  PROP  GPE
# 1307       4         9357       9357  PROP  GPE
# 1379      14         9736       9736  PROP  GPE
# 1473       4        10298      10298  PROP  GPE
# 1530      -1        10626      10629   NOM  GPE
# 1531       4        10629      10629  PROP  GPE
# 1668      34        11640      11640  PROP  GPE
# 1704      34        11902      11902  PROP  GPE
# 1706      34        11940      11940  PROP  GPE
# 1733      35        12148      12148  PROP  GPE
# 1734      36        12150      12150  PROP  GPE
# 1735      37        12152      12152  PROP  GPE
# 1766      41        12406      12407  PROP  GPE
# 1767      -1        12410      12411   NOM  GPE
# 1905      42        13372      13372  PROP  GPE
# 1908      10        13384      13384  PROP  GPE
# 1911      -1        13395      13397   NOM  GPE
# 1941      -1        13647      13648   NOM  GPE
# 1947      -1        13686      13688   NOM  GPE
# 2382      -1        16899      16900   NOM  GPE
# 2389      47        16962      16962  PROP  GPE
# 2391      45        16971      16974  PROP  GPE
# 2425      10        17262      17262  PROP  GPE
# 2450      -1        17398      17401   NOM  GPE
# 2452      45        17407      17410  PROP  GPE
# 2461      -1        17474      17475   NOM  GPE
# 2475      10        17596      17596  PROP  GPE
# 2480      -1        17615      17616   NOM  GPE
# 2574      52        18246      18246  PROP  GPE
# 2682      10        18886      18886  PROP  GPE
# 2691      55        18912      18912  PROP  GPE
# 2692      56        18914      18914  PROP  GPE
# 2701      57        18952      18952  PROP  GPE
# 2703      58        18965      18965  PROP  GPE
# 2799      -1        19602      19611   NOM  GPE
# 2801      10        19610      19610  PROP  GPE
# 2808      10        19637      19637  PROP  GPE
# 2817      60        19708      19708  PROP  GPE
# 2873      45        20114      20117  PROP  GPE
# 3026      10        21457      21457  PROP  GPE
# 3055      -1        21642      21643   NOM  GPE
# 3066      54        21673      21674  PROP  GPE
# 3117      -1        22024      22026   NOM  GPE
# 3177       8        22648      22648  PROP  GPE
# 3189      62        22812      22812  PROP  GPE
# 3200      63        22928      22928  PROP  GPE
# 3349      65        23862      23862  PROP  GPE
# 3350      66        23867      23868  PROP  GPE
# 3426      60        24308      24308  PROP  GPE
# 3439      60        24362      24362  PROP  GPE
# 3486      60        24617      24617  PROP  GPE
# 3562      60        25090      25090  PROP  GPE
# 3598      68        25277      25277  PROP  GPE
# 3606      14        25321      25321  PROP  GPE
# 3729      72        26124      26124  PROP  GPE
# 3730      73        26126      26126  PROP  GPE
# 3776      75        26412      26412  PROP  GPE
# 3877      -1        27530      27531   NOM  GPE
# 3900       4        27678      27678  PROP  GPE
# 4122      60        29406      29406  PROP  GPE
# 4131      60        29511      29511  PROP  GPE
# 4236      76        30351      30353  PROP  GPE
# 4261      14        30510      30510  PROP  GPE
# 4262      77        30514      30515  PROP  GPE
# 4265      78        30534      30534  PROP  GPE
# 4291      79        30680      30680  PROP  GPE
# 4335      77        31089      31090  PROP  GPE
# 4336      -1        31092      31102   NOM  GPE
# 4337     276        31099      31099  PROP  GPE
# 4338      82        31102      31102  PROP  GPE
# 4343      83        31122      31122  PROP  GPE
# 4373      -1        31291      31292   NOM  GPE
# 4385     317        31356      31356  PROP  GPE
# 4465      88        31759      31760  PROP  GPE
# 4502      -1        32100      32101   NOM  GPE
# 4510       9        32140      32140  PROP  GPE
# 4622      90        33084      33084  PROP  GPE
# 4630     276        33127      33127  PROP  GPE
# 4758      90        33756      33756  PROP  GPE
# 4836      91        34301      34301  PROP  GPE
# 4843      -1        34344      34351   NOM  GPE
# 4844     276        34351      34351  PROP  GPE
# 4851     325        34402      34402  PROP  GPE
# 5018      94        35346      35346  PROP  GPE
# 5081      95        35642      35642  PROP  GPE
# 5092      -1        35702      35704   NOM  GPE
# 5142      -1        36225      36226   NOM  GPE
# 5181      90        36504      36504  PROP  GPE
# 5207      90        36648      36648  PROP  GPE
# 5328      88        37499      37500  PROP  GPE
# 5366      -1        37812      37838   NOM  GPE
# 5474      10        38791      38791  PROP  GPE
# 5481      -1        38862      38864   NOM  GPE
# 5542      90        39216      39216  PROP  GPE
# 5550      88        39283      39284  PROP  GPE
# 5552      83        39291      39291  PROP  GPE
# 5555      -1        39326      39329   NOM  GPE
# 5556      94        39329      39329  PROP  GPE
# 5559      90        39339      39339  PROP  GPE
# 5580     340        39496      39496  PROP  GPE
# 5583      -1        39515      39516   NOM  GPE
# 5624      97        39860      39860  PROP  GPE
# 5779      -1        40808      40809   NOM  GPE
# 5782     340        40824      40824  PROP  GPE
# 5783      98        40826      40826  PROP  GPE
# 5810      14        40955      40955  PROP  GPE
# 5838      -1        41101      41101   NOM  GPE
# 5860      14        41191      41191  PROP  GPE
# 5863      -1        41210      41212   NOM  GPE
# 6032      -1        42320      42367   NOM  GPE
# 6037     100        42367      42367  PROP  GPE
# 6047      10        42523      42523  PROP  GPE
# 6126     101        43119      43119  PROP  GPE
# 6182     102        43460      43460  PROP  GPE
# 6191     103        43512      43512  PROP  GPE
# 6195     104        43524      43524  PROP  GPE
# 6210      11        43592      43592  PROP  GPE
# 6212     105        43599      43599  PROP  GPE
# 6213     106        43602      43602  PROP  GPE
# 6215     107        43612      43613  PROP  GPE
# 6229      -1        43688      43689   NOM  GPE
# 6254      14        43809      43809  PROP  GPE
# 6298     108        44054      44054  PROP  GPE
# 6340     109        44353      44353  PROP  GPE
# 6456     103        45242      45242  PROP  GPE
# 6463      -1        45280      45282   NOM  GPE
# 6501     110        45611      45611  PROP  GPE
# 6526     111        45783      45784  PROP  GPE
# 6540      -1        45859      45860   NOM  GPE
# 6546     112        45898      45898  PROP  GPE
# 6547      -1        45905      45906   NOM  GPE
# 6575     106        46119      46119  PROP  GPE
# 6585      10        46218      46218  PROP  GPE
# 6665     113        46850      46851  PROP  GPE
# 6668     362        46870      46870  PROP  GPE
# 6710     115        47209      47209  PROP  GPE
# 6721     106        47276      47276  PROP  GPE
# 6723      10        47288      47288  PROP  GPE
# 6787      -1        47933      47933   NOM  GPE
# 6817     103        48142      48142  PROP  GPE
# 6821     104        48163      48163  PROP  GPE
# 6822      -1        48169      48172   NOM  GPE
# 6824      14        48180      48180  PROP  GPE
# 6830     103        48214      48214  PROP  GPE
# 6838     110        48263      48263  PROP  GPE
# 6839      10        48269      48269  PROP  GPE
# 6840     116        48274      48275  PROP  GPE
# 6851     110        48360      48360  PROP  GPE
# 6862     110        48463      48463  PROP  GPE
# 6864     366        48470      48470  PROP  GPE
# 6877      10        48588      48588  PROP  GPE
# 6912      -1        48836      48838   NOM  GPE
# 6914      -1        48854      48855   NOM  GPE
# 6915     118        48859      48859  PROP  GPE
# 6916     119        48861      48861  PROP  GPE
# 6917     120        48863      48864  PROP  GPE
# 6918     121        48866      48866  PROP  GPE
# 6919     104        48869      48869  PROP  GPE
# 6922      -1        48893      48902   NOM  GPE
# 6927      -1        48960      48961   NOM  GPE
# 6937      -1        49058      49059   NOM  GPE
# 6942     103        49120      49120  PROP  GPE
# 6959      -1        49251      49252   NOM  GPE
# 6976      -1        49380      49382   NOM  GPE
# 6991     106        49466      49466  PROP  GPE
# 6994      -1        49488      49489   NOM  GPE
# 7022     106        49742      49742  PROP  GPE
# 7106     125        50340      50340  PROP  GPE
# 7107     121        50342      50342  PROP  GPE
# 7133      10        50529      50529  PROP  GPE
# 7134      -1        50539      50545   NOM  GPE
# 7135      -1        50541      50545   NOM  GPE
# 7136      -1        50544      50545   NOM  GPE
# 7137     126        50549      50549  PROP  GPE
# 7149      10        50630      50630  PROP  GPE
# 7155     125        50676      50676  PROP  GPE
# 7157     128        50681      50681  PROP  GPE
# 7162     130        50714      50717  PROP  GPE
# 7183     125        50806      50806  PROP  GPE
# 7186     125        50826      50826  PROP  GPE
# 7195     125        50915      50915  PROP  GPE
# 7206     132        51001      51001  PROP  GPE
# 7209     199        51009      51010  PROP  GPE
# 7309      -1        51623      51624   NOM  GPE
# 7319     135        51706      51706  PROP  GPE
# 7331      -1        51773      51774   NOM  GPE
# 7396      -1        52299      52299   NOM  GPE
# 7601     140        53636      53636  PROP  GPE
# 7685      -1        54221      54221   NOM  GPE
# 7701      -1        54353      54353   NOM  GPE
# 7726      -1        54487      54488   NOM  GPE
# 7762      -1        54707      54707   NOM  GPE
# 7860      -1        55474      55475   NOM  GPE
# 8013      -1        56752      56754   NOM  GPE
# 8021      -1        56789      56791   NOM  GPE
# 8024     353        56810      56810  PROP  GPE
# 8030     146        56832      56832  PROP  GPE
# 8031     147        56839      56839  PROP  GPE
# 8032     140        56844      56844  PROP  GPE
# 8180     128        58042      58042  PROP  GPE
# 8191     128        58112      58112  PROP  GPE
# 8333      11        59209      59209  PROP  GPE
# 8361      -1        59384      59385   NOM  GPE
# 8363      -1        59401      59402   NOM  GPE
# 8367      -1        59461      59461   NOM  GPE
# 8372     147        59482      59482  PROP  GPE
# 8502      -1        60336      60339   NOM  GPE
# 8579     153        60885      60885  PROP  GPE
# 8585      10        60915      60915  PROP  GPE
# 8608      -1        61075      61076   NOM  GPE
# 8630      -1        61206      61207   NOM  GPE
# 8646      -1        61338      61377   NOM  GPE
# 8654      -1        61377      61377   NOM  GPE
# 8668      10        61434      61434  PROP  GPE
# 8674      -1        61482      61483   NOM  GPE
# 8680      -1        61531      61532   NOM  GPE
# 8686      -1        61558      61559   NOM  GPE
# 8885      -1        63133      63136   NOM  GPE
# 9086     394        65186      65186  PROP  GPE
# 9095     394        65227      65227  PROP  GPE
# 9189      34        66072      66072  PROP  GPE
# 9367     165        67412      67412  PROP  GPE
# 9372     166        67437      67437  PROP  GPE
# 9483      -1        68243      68243   NOM  GPE
# 9495      -1        68307      68308   NOM  GPE
# 9496      -1        68310      68310   NOM  GPE
# 9823      -1        70466      70467   NOM  GPE
# 9881     173        70789      70789  PROP  GPE
# 9894     174        70850      70850  PROP  GPE
# 9924     174        71016      71016  PROP  GPE
# 10120     -1        72436      72437   NOM  GPE
# 10213    175        73052      73052  PROP  GPE
# 10215    115        73065      73065  PROP  GPE
# 10301     14        73547      73547  PROP  GPE
# 10303    415        73552      73553  PROP  GPE
# 10305    147        73560      73560  PROP  GPE
# 10312     14        73591      73591  PROP  GPE
# 10314    177        73601      73601  PROP  GPE
# 10315    178        73607      73607  PROP  GPE
# 10318     -1        73644      73645   NOM  GPE
# 10331    179        73733      73733  PROP  GPE
# 10340     14        73802      73802  PROP  GPE
# 10342    108        73815      73815  PROP  GPE
# 10366     14        73921      73921  PROP  GPE
# 10370    180        73937      73937  PROP  GPE
# 10374     10        73951      73951  PROP  GPE
# 10404     -1        74125      74126   NOM  GPE
# 10461    182        74449      74449  PROP  GPE
# 10466     -1        74477      74477   NOM  GPE
# 10641     -1        75529      75530   NOM  GPE
# 10666     -1        75727      75728   NOM  GPE
# 10729    175        76306      76306  PROP  GPE
# 10765    415        76538      76539  PROP  GPE
# 10771     -1        76573      76573   NOM  GPE
# 10787     -1        76683      76683   NOM  GPE
# 10973    115        78001      78001  PROP  GPE
# 10981    115        78057      78057  PROP  GPE
# 10984    175        78066      78066  PROP  GPE
# 11013     -1        78301      78301   NOM  GPE
# 11016     -1        78319      78320   NOM  GPE
# 11055     -1        78546      78546   NOM  GPE
# 11085    182        78697      78697  PROP  GPE
# 11534     -1        82575      82576   NOM  GPE
# 11575    108        82952      82952  PROP  GPE
# 11597    182        83141      83141  PROP  GPE
# 11625    108        83428      83428  PROP  GPE
# 11713     78        84283      84283  PROP  GPE
# 11773     78        84622      84622  PROP  GPE
# 11834     -1        85108      85110   NOM  GPE
# 11964     10        85922      85922  PROP  GPE
# 11973    186        85961      85961  PROP  GPE
# 12038     10        86403      86403  PROP  GPE
# 12113    187        86944      86944  PROP  GPE
# 12114    177        86947      86947  PROP  GPE
# 12117    188        86958      86958  PROP  GPE
# 12120     78        86972      86972  PROP  GPE
# 12127     -1        87024      87025   NOM  GPE
# 12165     14        87336      87336  PROP  GPE
# 12168     -1        87359      87368   NOM  GPE
# 12213    187        87670      87670  PROP  GPE
# 12268     78        88032      88032  PROP  GPE
# 12276    187        88077      88077  PROP  GPE
# 12390    187        89014      89014  PROP  GPE
# 12393     -1        89045      89047   NOM  GPE
# 12394     -1        89055      89061   NOM  GPE
# 12396     -1        89081      89082   NOM  GPE
# 12781     -1        92077      92077   NOM  GPE
# 12815    187        92372      92372  PROP  GPE
# 12818    190        92391      92391  PROP  GPE
# 12819     -1        92393      92396   NOM  GPE
# 12822     54        92411      92412  PROP  GPE
# 12826     -1        92430      92431   NOM  GPE
# 12831     -1        92472      92473   NOM  GPE
# 12872     -1        92710      92711   NOM  GPE
# 12925    189        93109      93110  PROP  GPE
# 12936     -1        93200      93202   NOM  GPE
# 13019     10        93883      93883  PROP  GPE
# 13073     14        94387      94387  PROP  GPE
# 13147    193        94923      94923  PROP  GPE
# 13153    194        94991      94991  PROP  GPE
# 13179    193        95212      95212  PROP  GPE
# 13183    195        95230      95231  PROP  GPE
# 13184    196        95233      95233  PROP  GPE
# 13185     37        95236      95236  PROP  GPE
# 13192    197        95328      95329  PROP  GPE
# 13209    193        95466      95466  PROP  GPE
# 13214    198        95496      95496  PROP  GPE
# 13229    202        95657      95657  PROP  GPE
# 13259    193        96000      96000  PROP  GPE
# 13400    195        97112      97113  PROP  GPE
# 13402     -1        97125      97126   NOM  GPE
# 13440     14        97331      97331  PROP  GPE
# 13467     10        97532      97532  PROP  GPE
# 13473     10        97554      97554  PROP  GPE
# 13549    203        98064      98064  PROP  GPE
# 13556    103        98102      98102  PROP  GPE
# 13724    206        99242      99242  PROP  GPE
# 13725    207        99256      99256  PROP  GPE
# 13726    208        99261      99264  PROP  GPE
# 14017    103       101412     101412  PROP  GPE
# 14026    211       101469     101469  PROP  GPE
# 14079    463       101744     101744  PROP  GPE
# 14083    213       101757     101757  PROP  GPE
# 14085    214       101765     101765  PROP  GPE
# 14088    215       101774     101775  PROP  GPE
# 14099    216       101836     101837  PROP  GPE
# 14103    216       101868     101869  PROP  GPE
# 14105     10       101875     101875  PROP  GPE
# 14186    203       102260     102260  PROP  GPE
# 14230    216       102475     102476  PROP  GPE
# 14233     14       102491     102491  PROP  GPE
# 14261    218       102680     102680  PROP  GPE
# 14363    103       103309     103309  PROP  GPE
# 14365     -1       103319     103320   NOM  GPE
# 14416     10       103668     103668  PROP  GPE
# 14601    221       104857     104860  PROP  GPE
# 14603     10       104877     104877  PROP  GPE
# 14647     14       105193     105193  PROP  GPE
# 14694     -1       105560     105561   NOM  GPE
# 14762    222       106153     106153  PROP  GPE
# 15169     -1       108488     108489   NOM  GPE
# 15333    222       109505     109505  PROP  GPE
# 15353     -1       109625     109627   NOM  GPE
# 15365    223       109698     109698  PROP  GPE
# 15367    223       109708     109708  PROP  GPE
# 15448     10       110267     110267  PROP  GPE
# 15737    222       112122     112122  PROP  GPE
# 15932     14       113371     113371  PROP  GPE
# 16225    222       115190     115190  PROP  GPE
# 16278     14       115500     115500  PROP  GPE
# 16367      4       116304     116304  PROP  GPE
# 16464    226       116972     116972  PROP  GPE
# 16465    227       116975     116976  PROP  GPE
# 16468    103       116984     116984  PROP  GPE
# 16478    228       117050     117051  PROP  GPE
# 16479    229       117053     117054  PROP  GPE
# 16542     -1       117516     117517   NOM  GPE
# 16578    178       117752     117752  PROP  GPE
# 16581    230       117769     117769  PROP  GPE
# 16703     14       118549     118549  PROP  GPE
# 16721    230       118661     118661  PROP  GPE
# 16748    231       118807     118807  PROP  GPE
# 16765    230       118932     118932  PROP  GPE
# 16839    178       119447     119447  PROP  GPE
# 16844    230       119475     119475  PROP  GPE
# 16892    232       119849     119849  PROP  GPE
# 16896    230       119881     119881  PROP  GPE
# 16908    230       119963     119963  PROP  GPE
# 16915     -1       120014     120017   NOM  GPE
# 16918    178       120038     120039  PROP  GPE
# 16924    234       120115     120115  PROP  GPE
# 16954     10       120310     120310  PROP  GPE
# 16958     -1       120351     120352   NOM  GPE
# 16970    230       120500     120500  PROP  GPE
# 16975    230       120545     120545  PROP  GPE
# 17017     -1       120789     120789   NOM  GPE
# 17084    231       121195     121195  PROP  GPE
# 17264     -1       122452     122452   NOM  GPE
# 17363     10       123158     123158  PROP  GPE
# 17482     -1       123989     123990   NOM  GPE
# 17562     -1       124686     124686   NOM  GPE
# 17624    230       125034     125034  PROP  GPE
# 17694    103       125445     125445  PROP  GPE
# 17999     10       127281     127281  PROP  GPE
# 18033    230       127474     127474  PROP  GPE
# 18049    237       127578     127578  PROP  GPE
# 18054    238       127599     127599  PROP  GPE
# 18065    239       127648     127648  PROP  GPE
#
#                                                                                                                                                                                                                                                                   text
# 9                                                                                                                                                                                                                                                              BOHEMIA
# 62                                                                                                                                                                                                                                                              Odessa
# 65                                                                                                                                                                                                                                                         Trincomalee
# 68                                                                                                                                                                                                                                                             Holland
# 83                                                                                                                                                                                                                                                             Scarlet
# 174                                                                                                                                                                                                                                                             London
# 229                                                                                                                                                                                                                                                             Europe
# 264                                                                                                                                                                                                                                        a German - speaking country
# 265                                                                                                                                                                                                                                                            Bohemia
# 266                                                                                                                                                                                                                                                           Carlsbad
# 267                                                                                                                                                                                                                                                        Wallenstein
# 274                                                                                                                                                                                                                                                            Bohemia
# 316                                                                                                                                                                                                                                                            England
# 394                                                                                                                                                                                                                                                             Europe
# 396                                                                                                                                                                                                                                                           Ormstein
# 398                                                                                                                                                                                                                                                            Bohemia
# 409                                                                                                                                                                                                                                                             Europe
# 436                                                                                                                                                                                                                                    Grand Duke of Cassel - Felstein
# 438                                                                                                                                                                                                                                                            Bohemia
# 453                                                                                                                                                                                                                                                             Prague
# 457                                                                                                                                                                                                                                                             Warsaw
# 477                                                                                                                                                                                                                                                         New Jersey
# 480                                                                                                                                                                                                                                                             Warsaw
# 481                                                                                                                                                                                                                                                             London
# 529                                                                                                                                                                                                                                                        Scandinavia
# 559                                                                                                                                                                                                                                                             London
# 562                                                                                                                                                                                                                                                        the Langham
# 573                                                                                                                                                                                                                                 one of the provinces of my kingdom
# 574                                                                                                                                                                                                                                        the provinces of my kingdom
# 794                                                                                                                                                                                                                                                         St. Monica
# 810                                                                                                                                                                                                                                                         St. Monica
# 1180                                                                                                                                                                                                                                                            uproar
# 1236                                                                                                                                                                                                                                                  Arnsworth Castle
# 1307                                                                                                                                                                                                                                                           Bohemia
# 1379                                                                                                                                                                                                                                                           England
# 1473                                                                                                                                                                                                                                                           Bohemia
# 1530                                                                                                                                                                                                                                            the kingdom of Bohemia
# 1531                                                                                                                                                                                                                                                           Bohemia
# 1668                                                                                                                                                                                                                                                             China
# 1704                                                                                                                                                                                                                                                             China
# 1706                                                                                                                                                                                                                                                             China
# 1733                                                                                                                                                                                                                                                           Lebanon
# 1734                                                                                                                                                                                                                                                      Pennsylvania
# 1735                                                                                                                                                                                                                                                            U.S.A.
# 1766                                                                                                                                                                                                                                                     Coburg Square
# 1767                                                                                                                                                                                                                                                          the City
# 1905                                                                                                                                                                                                                                                         Londoners
# 1908                                                                                                                                                                                                                                                            London
# 1911                                                                                                                                                                                                                                                      the old town
# 1941                                                                                                                                                                                                                                                          the city
# 1947                                                                                                                                                                                                                                                 the whole country
# 2382                                                                                                                                                                                                                                                          the City
# 2389                                                                                                                                                                                                                                                        Aldersgate
# 2391                                                                                                                                                                                                                                              Saxe - Coburg Square
# 2425                                                                                                                                                                                                                                                            London
# 2450                                                                                                                                                                                                                                               an enemy ’s country
# 2452                                                                                                                                                                                                                                              Saxe - Coburg Square
# 2461                                                                                                                                                                                                                                                          the City
# 2475                                                                                                                                                                                                                                                            London
# 2480                                                                                                                                                                                                                                                          the City
# 2574                                                                                                                                                                                                                                                        Kensington
# 2682                                                                                                                                                                                                                                                            London
# 2691                                                                                                                                                                                                                                                              Eton
# 2692                                                                                                                                                                                                                                                            Oxford
# 2701                                                                                                                                                                                                                                                          Scotland
# 2703                                                                                                                                                                                                                                                          Cornwall
# 2799                                                                                                                                                                                                              the City branch of one of the principal London banks
# 2801                                                                                                                                                                                                                                                            London
# 2808                                                                                                                                                                                                                                                            London
# 2817                                                                                                                                                                                                                                                            France
# 2873                                                                                                                                                                                                                                              Saxe - Coburg Square
# 3026                                                                                                                                                                                                                                                            London
# 3055                                                                                                                                                                                                                                                          the City
# 3066                                                                                                                                                                                                                                                     Scotland Yard
# 3117                                                                                                                                                                                                                                                   this great city
# 3177                                                                                                                                                                                                                                                           Holland
# 3189                                                                                                                                                                                                                                                        Marseilles
# 3200                                                                                                                                                                                                                                                        Devonshire
# 3349                                                                                                                                                                                                                                                          Auckland
# 3350                                                                                                                                                                                                                                                       New Zealand
# 3426                                                                                                                                                                                                                                                            France
# 3439                                                                                                                                                                                                                                                            France
# 3486                                                                                                                                                                                                                                                            France
# 3562                                                                                                                                                                                                                                                            France
# 3598                                                                                                                                                                                                                                                          Bordeaux
# 3606                                                                                                                                                                                                                                                           England
# 3729                                                                                                                                                                                                                                                         Westhouse
# 3730                                                                                                                                                                                                                                                           Marbank
# 3776                                                                                                                                                                                                                                                           Andover
# 3877                                                                                                                                                                                                                                                          the City
# 3900                                                                                                                                                                                                                                                           Bohemia
# 4122                                                                                                                                                                                                                                                            France
# 4131                                                                                                                                                                                                                                                            France
# 4236                                                                                                                                                                                                                                               Westhouse & Marbank
# 4261                                                                                                                                                                                                                                                           England
# 4262                                                                                                                                                                                                                                                   Boscombe Valley
# 4265                                                                                                                                                                                                                                                        Paddington
# 4291                                                                                                                                                                                                                                                       Afghanistan
# 4335                                                                                                                                                                                                                                                   Boscombe Valley
# ...
# 14186                                                                                                                                                                                                                                                       California
# 14230                                                                                                                                                                                                                                                         ’ Frisco
# 14233                                                                                                                                                                                                                                                          England
# 14261                                                                                                                                                                                                                                                            Paris
# 14363                                                                                                                                                                                                                                                          America
# 14365                                                                                                                                                                                                                                                     this country
# 14416                                                                                                                                                                                                                                                           London
# 14601                                                                                                                                                                                                                                               the City of London
# 14603                                                                                                                                                                                                                                                           London
# 14647                                                                                                                                                                                                                                                          England
# 14694                                                                                                                                                                                                                                                       the empire
# 14762                                                                                                                                                                                                                                                        Streatham
# 15169                                                                                                                                                                                                                                                       the nation
# 15333                                                                                                                                                                                                                                                        Streatham
# 15353                                                                                                                                                                                                                                              the southern suburb
# 15365                                                                                                                                                                                                                                                         Fairbank
# 15367                                                                                                                                                                                                                                                         Fairbank
# 15448                                                                                                                                                                                                                                                           London
# 15737                                                                                                                                                                                                                                                        Streatham
# 15932                                                                                                                                                                                                                                                          England
# 16225                                                                                                                                                                                                                                                        Streatham
# 16278                                                                                                                                                                                                                                                          England
# 16367                                                                                                                                                                                                                                                          Bohemia
# 16464                                                                                                                                                                                                                                                          Halifax
# 16465                                                                                                                                                                                                                                                      Nova Scotia
# 16468                                                                                                                                                                                                                                                          America
# 16478                                                                                                                                                                                                                                                         West End
# 16479                                                                                                                                                                                                                                                      Westaway ’s
# 16542                                                                                                                                                                                                                                                      the country
# 16578                                                                                                                                                                                                                                                        Hampshire
# 16581                                                                                                                                                                                                                                                       Winchester
# 16703                                                                                                                                                                                                                                                          England
# 16721                                                                                                                                                                                                                                                       Winchester
# 16748                                                                                                                                                                                                                                                     Philadelphia
# 16765                                                                                                                                                                                                                                                       Winchester
# 16839                                                                                                                                                                                                                                                        Hampshire
# 16844                                                                                                                                                                                                                                                       Winchester
# 16892                                                                                                                                                                                                                                                         Bradshaw
# 16896                                                                                                                                                                                                                                                       Winchester
# 16908                                                                                                                                                                                                                                                       Winchester
# 16915                                                                                                                                                                                                                                          the old English capital
# 16918                                                                                                                                                                                                                                                 Hampshire border
# 16924                                                                                                                                                                                                                                                        Aldershot
# 16954                                                                                                                                                                                                                                                           London
# 16958                                                                                                                                                                                                                                                         the town
# 16970                                                                                                                                                                                                                                                       Winchester
# 16975                                                                                                                                                                                                                                                       Winchester
# 17017                                                                                                                                                                                                                                                             town
# 17084                                                                                                                                                                                                                                                     Philadelphia
# 17264                                                                                                                                                                                                                                                            there
# 17363                                                                                                                                                                                                                                                           London
# 17482                                                                                                                                                                                                                                                       this place
# 17562                                                                                                                                                                                                                                                            there
# 17624                                                                                                                                                                                                                                                       Winchester
# 17694                                                                                                                                                                                                                                                          America
# 17999                                                                                                                                                                                                                                                           London
# 18033                                                                                                                                                                                                                                                       Winchester
# 18049                                                                                                                                                                                                                                                      Southampton
# 18054                                                                                                                                                                                                                                                        Mauritius
# 18065                                                                                                                                                                                                                                                          Walsall

# %% [markdown]
# ## Your turn!

# %% [markdown]
# ### Question 1:
# Compare the output of `spaCy` [generated list of place names](#Generate-a-list-of-place-names-from-our-spaCy-document) with the [generated list of place names from `BookNLP`](#Generating-a-list-of-place-names-from-our--BookNLP-dataframe). What do you notice?

# %% [markdown]
# [TYPE YOUR REFLECTION HERE]

# %% [markdown]
# ### Question 2
# Look at the dataframe we created above, `sherlock_holmes_entities_df`. Using the `pandas` methods that we've learned thus far, output the number of each values that appear.

# %%
## YOUR CODE HERE

# %% [markdown]
# ### Question 3
#
# + 3a. Sticking with models we've just run on *The Adventures of Sherlock Holmes*, generate a list of "facility" names in `spaCy` (this is the 'FAC' tag) and generate a list of "facility" names from the `BookNLP` dataframe.
# + 3b. How do they compare?

# %%
## YOUR CODE HERE

# %% [markdown]
# [TYPE YOUR REFLECTION HERE]

# %% [markdown]
# ### Question 4:
#
# + 4a. Using `spaCy` and read in a new text from our "../datasets/texts/literature/" folder.
# + 4b. Run the NER model on that text
# + 4c. Generate a list of all the "GPE" tagged strings of text
# + 4d. Using the `displacy` visualizer, save an HTML visualization of the full tagged text of your chosen work

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# ### Question 5:
#
# + 5a. Run `BookNLP` on the text from Question 4 (remember to replace the filepath, book directory and book ID fields in the code)
# + 5b. Generate a dataframe from the BookNLP output on your chosen text
# + 5c. Using that dataframe, generate list of all the "GPE" tagged strings of text

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE
